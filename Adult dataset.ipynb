# %%
#Importing Libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing data
data=pd.read_csv("C:/Users/DC/Downloads/adult.csv")
df=pd.DataFrame(data)
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
#Checking datatypes
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# y                 object
# dtype: object

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'y'],
#       dtype='object')

# %%
#dataset description
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.shape
# Out:
# (32561, 15)

# %%
#LabelEncoder to change object variables to int
a=['workclass','education','marital-status','occupation','relationship','race','sex','native-country','y']
import sklearn
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in a:
    df[i]=le.fit_transform(df[i].astype(str))
df
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
df.dtypes
# Out:
# age               int64
# workclass         int32
# fnlwgt            int64
# education         int32
# education-num     int64
# marital-status    int32
# occupation        int32
# relationship      int32
# race              int32
# sex               int32
# capital-gain      int64
# capital-loss      int64
# hours-per-week    int64
# native-country    int32
# y                 int32
# dtype: object

# %%
df.describe()
# Out:
#                 age     workclass        fnlwgt     education  education-num  \
# count  32561.000000  32561.000000  3.256100e+04  32561.000000   32561.000000
# mean      38.581647      3.868892  1.897784e+05     10.298210      10.080679
# std       13.640433      1.455960  1.055500e+05      3.870264       2.572720
# min       17.000000      0.000000  1.228500e+04      0.000000       1.000000
# 25%       28.000000      4.000000  1.178270e+05      9.000000       9.000000
# 50%       37.000000      4.000000  1.783560e+05     11.000000      10.000000
# 75%       48.000000      4.000000  2.370510e+05     12.000000      12.000000
# max       90.000000      8.000000  1.484705e+06     15.000000      16.000000
#
#        marital-status    occupation  relationship          race           sex  \
# count    32561.000000  32561.000000  32561.000000  32561.000000  32561.000000
# mean         2.611836      6.572740      1.446362      3.665858      0.669205
# ...

# %%
#Outliers check and treatment 
from scipy.stats import zscore 
threhold=3 
z=np.abs(zscore(df)) 
print(np.where(z>3))
# Out:
# (array([    4,    10,    11, ..., 32533, 32551, 32553], dtype=int64), array([13, 12,  8, ...,  8,  8,  8], dtype=int64))

# %%
df=df[(z<3).all(axis=1)]
df
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 5       37          4  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# y                 0
# dtype: int64

# %%
#Checking skewness which will be treated after univariate and bivariate analysis
df.skew()
# Out:
# age                0.483480
# workclass         -0.737714
# fnlwgt             0.626258
# education         -0.957433
# education-num     -0.144018
# marital-status    -0.044388
# occupation         0.131200
# relationship       0.750249
# race              -2.592997
# sex               -0.684173
# capital-gain       4.934777
# capital-loss      29.326272
# hours-per-week    -0.358404
# native-country    -5.460784
# y                  1.324975
# dtype: float64

# %%
df.corr()
# Out:
#                      age  workclass    fnlwgt  education  education-num  \
# age             1.000000   0.005555 -0.077697  -0.003469       0.044082
# workclass       0.005555   1.000000 -0.021297   0.021519       0.049627
# fnlwgt         -0.077697  -0.021297  1.000000  -0.021100      -0.040548
# education      -0.003469   0.021519 -0.021100   1.000000       0.347354
# education-num   0.044082   0.049627 -0.040548   0.347354       1.000000
# marital-status -0.285859  -0.061672  0.029706  -0.036828      -0.058368
# occupation     -0.015550   0.249353 -0.002959  -0.023460       0.111011
# relationship   -0.270293  -0.089912  0.016321  -0.010708      -0.094425
# race            0.019111   0.063237 -0.104191   0.026793       0.085845
# sex             0.088656   0.092436  0.022072  -0.030869       0.003960
# capital-gain    0.132075   0.025085 -0.003411   0.026497       0.157660
# capital-loss    0.023576  -0.007680  0.003244  -0.000367       0.007581
# ...

# %%
#Correlation 
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# Sex has significant negetive correlation with relationship. Otherwise no significant correlation found between the variables.

# %% [markdown]
# EDA-Univariate and Bivariate Analysis

# %%
plt.figure()
df['age'].plot(kind='hist',bins=20)

# %% [markdown]
# Age<20 has the highest frequency.

# %%
plt.figure()
df['workclass'].plot(kind='hist')

# %% [markdown]
# Workclass=4 has the highest frequency.

# %%
plt.figure()
df['fnlwgt'].plot(kind='hist',bins=20)

# %% [markdown]
# fnlwgt=160000 (approx) has the highest frequency.

# %%
plt.figure()
df['education'].plot(kind='hist')

# %% [markdown]
# Education=11 has the highest frequency.

# %%
plt.figure()
df['education-num'].plot(kind='hist')

# %% [markdown]
# education-num=9 has the highest frequency.

# %%
plt.figure()
df['marital-status'].plot(kind='hist')

# %% [markdown]
# Marital status=2 has the highest frequency.

# %%
plt.figure()
df['occupation'].plot(kind='hist')

# %% [markdown]
# Occupation=3 has the highest frequency.

# %%
plt.figure()
df['relationship'].plot(kind='hist')

# %% [markdown]
# Relationship=0 has the highest frequency.

# %%
plt.figure()
df['race'].plot(kind='hist')

# %% [markdown]
# Race=4 has the highest frequency

# %%
plt.figure()
df['sex'].plot(kind='hist')

# %% [markdown]
# Sex=1 has the highest frequency

# %%
plt.figure()
df['capital-gain'].plot(kind='hist',bins=20)

# %% [markdown]
# capital gain=0 to 1000 has the highest frequency

# %%
plt.figure()
df['capital-loss'].plot(kind='hist')

# %% [markdown]
# capital-loss=0 has the highest frequency

# %%
plt.figure()
df['hours-per-week'].plot(kind='hist')

# %% [markdown]
# hours per week=35(approx) has the highest frequency

# %%
plt.figure()
df['native-country'].plot(kind='hist')

# %% [markdown]
# native country=40 has the highest frquency.

# %%
plt.figure()
df['y'].plot(kind='hist')

# %% [markdown]
# y=0 has the highest freequency. It is the dependant variable.

# %%
plt.figure()
sns.pairplot(df)

# %%
df_new=df.drop(['fnlwgt'],axis=1)
for i in df_new.columns:
    plt.figure()
    sns.lineplot(i,'y',data=df)

# %%
for i in df_new.columns:
    plt.figure()
    sns.barplot(i,'y',data=df_new)

# %% [markdown]
# As age increases chance of y=1 increases with highest chance at age=50.workclass=3 and 8 have y=0 and 5 has the highest chance of y=1.Education=10 has the highest chance of y=1 and 4 has the highes chance of y=0. As education increases from levels 0-15 chances of y=1 increases. As education-num increases, chance of y=1 increases. education-num=16 has the highest chance of y=1 while 3 has the highest chance of y=0. Marital status=1 has the highest chance of y=1 while 4 has the highest chance of y=0. Occupation=4 has the highest chance of y=1 and 9 & 2 has the highest chance of y=0. Relationship=5 has the highest chance of y=1 and 3 has the highest chance of y=0. Race=4 has the highest chance of y=1 and 3 has the highest chance of y=0. Sex=1 has the highest chance of y=1 and sex=0 has the highest chance of y=0. Chance of y=1 increases with increase in capital gain. Capital loss=65.3 has the highest chance of y=1 and other values of capital loss leads to y=0. Chance of y=1 increases with increase in hours per week. Native country=36 has the highest chance of y=1 and 16,17,28,40 has the highest chance of y=0.

# %%
df.skew()
dfn=df.drop(['y'],axis=1)

# %%
#skewness treatment
for i in dfn.columns:
    if df.skew().loc[i]>0.55:
        df[i]=df[i].apply(lambda x:np.log(x+1))

# %%
#X y division of data
x=df.drop(['y'],axis=1)
y=df['y']
y=y.values.reshape(-1,1)
y.shape
# Out:
# (27418, 1)

# %%
#scaling the data
import sklearn
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
dx=scale.fit_transform(x)
x=pd.DataFrame(dx,columns=x.columns)
x
# Out:
#             age  workclass    fnlwgt  education  education-num  \
# 0      0.062802   2.164940 -1.166618  -0.345718       1.221835
# 1      0.882752   1.474213 -1.049563  -0.345718       1.221835
# 2     -0.011739   0.092759  0.494563   0.170000      -0.438300
# 3      1.106375   0.092759  0.632178  -2.408590      -1.268367
# 4     -0.086280   0.092759  0.944921   0.427859       1.636869
# ...         ...        ...       ...        ...            ...
# 27413 -0.831690   0.092759  0.781310  -0.861436       0.806801
# 27414  0.137343   0.092759 -0.048139   0.170000      -0.438300
# 27415  1.479080   0.092759 -0.074262   0.170000      -0.438300
# 27416 -1.204395   0.092759  0.384324   0.170000      -0.438300
# 27417  1.031834   0.783486  0.963894   0.170000      -0.438300
#
#        marital-status  occupation  relationship      race       sex  \
# 0            0.912514   -1.306027     -0.000663  0.344056  0.714819
# 1           -0.403253   -0.599235     -1.068702  0.344056  0.714819
# ...

# %% [markdown]
# Modelling the data- Since y variable is categorical classification and logistic regression is used.

# %%
#Importing Libraries
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,auc
from sklearn.model_selection import cross_val_score

# %%
# getting the best random state for train test split
def max_score(model):
    max_score=0
    for r_state in range(42,100):
        xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=r_state,test_size=0.20)
        model.fit(xtrain,ytrain)
        ypred=model.predict(xtest)
        accuracy=accuracy_score(ytest,ypred)
        if accuracy>max_score:
            max_score=accuracy
            final_r_state=r_state
    print(max_score,'is max accuracy against r_state',final_r_state)

# %%
logr=LogisticRegression()
max_score(logr)
# Out:
# 0.8386214442013129 is max accuracy against r_state 93

# %%
#finding best parameters for knn
algo=KNeighborsClassifier()
para={'n_neighbors':[3,5,7,9,11]}
grid=GridSearchCV(estimator=algo,param_grid=para)
grid.fit(x,y)

print(grid.best_params_)
# Out:
# {'n_neighbors': 11}

# %%
knc=KNeighborsClassifier(n_neighbors=11)
max_score(knc)
# Out:
# 0.8475565280816922 is max accuracy against r_state 85

# %%
algo=SVC()
para={'kernel':['rbf','poly','linear'],'C':[1,10]}
grid=GridSearchCV(estimator=algo,param_grid=para)
grid.fit(x,y)

print(grid.best_params_)
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
svc=SVC(C= 10, kernel= 'rbf')
max_score(svc)
# Out:
# 0.8617797228300511 is max accuracy against r_state 93

# %%
algo=DecisionTreeClassifier()
para={'criterion':['gini','entropy']}
grid=GridSearchCV(estimator=algo,param_grid=para)
grid.fit(x,y)

print(grid.best_params_)
# Out:
# {'criterion': 'entropy'}

# %%
dtc=DecisionTreeClassifier(criterion='entropy')
max_score(dtc)
# Out:
# 0.8194748358862144 is max accuracy against r_state 50

# %%
algo=RandomForestClassifier()
para={'n_estimators':[50,100,150,200,500]}
grid=GridSearchCV(estimator=algo,param_grid=para)
grid.fit(x,y)

print(grid.best_params_)
# Out:
# {'n_estimators': 150}

# %%
rfc=RandomForestClassifier(n_estimators=150)
max_score(rfc)
# Out:
# 0.8650619985412108 is max accuracy against r_state 43

# %%
#using Boosting to improve accuracy
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier

# %%
#algo=AdaBoostClassifier()
#para={'n_estimators':[50,100,150,200,500]}
#grid=GridSearchCV(estimator=algo,param_grid=para)
#grid.fit(x,y)

#print(grid.best_params_)
# Out:
# {'n_estimators': 500}

# %%
#ad=AdaBoostClassifier(n_estimators=500,base_estimator=svc,algorithm='SAMME')
#max_score(ad)

# %%
algo=GradientBoostingClassifier()
para={'learning_rate':[1,0.1,0.01,0.001,0]}
grid=GridSearchCV(estimator=algo,param_grid=para)
grid.fit(x,y)

print(grid.best_params_)
# Out:
# {'learning_rate': 0.1}

# %%
gdb=GradientBoostingClassifier(learning_rate=0.1)
max_score(gdb)
# Out:
# 0.87436177972283 is max accuracy against r_state 93

# %%
models=[]
models.append(('Logistic Regression',logr,93))
models.append(('Support Vector Classifier',svc,93))
models.append(('KNeighborsClassifier',knc,85))
models.append(('Decision tree Classifier',dtc,75))
models.append(('RandomForest Classifier',rfc,93))
#models.append(('AdaBoost Classifier',ad,93))
models.append(('Gradient Boosting Classifier',gdb,93))

Models=[]
Accuracy=[]
Cvs=[]
Roc_score=[]

# %%
for name,model,randomstate in models:
    print('***********',name,'************')
    print('\n')
    Models.append(name)
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=randomstate,test_size=0.20)
    model.fit(xtrain,ytrain)
    print(model)
    pred=model.predict(xtest)
    print('\n')
    Ac=accuracy_score(ytest,pred)
    print('Accuracy score=',Ac)
    Accuracy.append(Ac*100)
    print('\n')
    cvs=cross_val_score(model,x,y,cv=5,scoring='accuracy').mean()
    print('Cross Validation Score=',cvs)
    Cvs.append(cvs)
    print('\n')
    Cr=classification_report(ytest,pred)
    print(Cr)
    print('\n')
    cm=confusion_matrix(ytest,pred)
    print(cm)
    fpr,tpr,threshold=roc_curve(ytest,pred)
    roc_auc=auc(fpr,tpr)
    print('Roc score=',roc_auc)
    Roc_score.append(roc_auc)
    print('\n')
    
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot(fpr,tpr,label='AUC=%0.2f'%roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True Positive Rate')
    
    print('\n\n')
# Out:
# *********** Logistic Regression ************
#
#
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
#
# Accuracy score= 0.8386214442013129
#
#
# Cross Validation Score= 0.8279962680218536
#
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90      4275
#            1       0.72      0.44      0.55      1209
#
#     accuracy                           0.84      5484
#    macro avg       0.79      0.70      0.73      5484
# weighted avg       0.83      0.84      0.82      5484
#
#
#
# [[4062  213]
#  [ 672  537]]
# Roc score= 0.6971720865439033
#
#
# AxesSubplot(0.125,0.808774;0.62x0.0712264)
#
#
#
# *********** Support Vector Classifier ************
#
# ...

# %%
Result=pd.DataFrame({'Models':Models,'Accuracy':Accuracy,'Cross Validation Score':Cvs,'Roc_Score':Roc_score})
Result
# Out:
#                          Models   Accuracy  Cross Validation Score  Roc_Score
# 0           Logistic Regression  83.862144                0.827996   0.697172
# 1     Support Vector Classifier  86.177972                0.850026   0.748212
# 2          KNeighborsClassifier  84.755653                0.834780   0.755633
# 3      Decision tree Classifier  82.348651                0.811292   0.753939
# 4       RandomForest Classifier  86.177972                0.852615   0.769567
# 5  Gradient Boosting Classifier  87.436178                0.864359   0.771112

# %% [markdown]
# Gradient boosting classifer is the best model

# %%
#saving the model
from sklearn.externals import joblib
joblib.dump(gdb,'gdb.Adult.obj')
# Out:
# ['gdb.Adult.obj']
