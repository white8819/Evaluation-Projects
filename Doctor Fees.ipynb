# %%
#Importing libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing dataset
data_train=pd.read_csv("C:/Users/DC/Downloads/Final_Train.csv")
train=pd.DataFrame(data_train)
train
# Out:
#                        Qualification           Experience Rating  \
# 0              BHMS, MD - Homeopathy  24 years experience   100%
# 1       BAMS, MD - Ayurveda Medicine  12 years experience    98%
# 2     MBBS, MS - Otorhinolaryngology   9 years experience    NaN
# 3                BSc - Zoology, BAMS  12 years experience    NaN
# 4                               BAMS  20 years experience   100%
# ...                              ...                  ...    ...
# 5956                  MBBS, MS - ENT  19 years experience    98%
# 5957                            MBBS  33 years experience    NaN
# 5958                            MBBS  41 years experience    97%
# 5959     MBBS, MD - General Medicine  15 years experience    90%
# 5960         BDS, MDS - Orthodontics  17 years experience   100%
#
#                               Place           Profile  \
# 0               Kakkanad, Ernakulam         Homeopath
# 1             Whitefield, Bangalore          Ayurveda
# ...

# %%
#Importing dataset
data_test=pd.read_csv("C:/Users/DC/Downloads/Final_Test.csv")
test=pd.DataFrame(data_test)
test
# Out:
#                                         Qualification           Experience  \
# 0                                                MBBS  35 years experience
# 1          MBBS, Diploma in Otorhinolaryngology (DLO)  31 years experience
# 2                                          MBBS, DDVL  40 years experience
# 3                                                BAMS   0 years experience
# 4     BDS, MDS - Conservative Dentistry & Endodontics  16 years experience
# ...                                               ...                  ...
# 1982                         BAMS, Doctor of Medicine  10 years experience
# 1983   MD - Dermatology , Venereology & Leprosy, MBBS   4 years experience
# 1984         MBBS, MD / MS - Obstetrics & Gynaecology   9 years experience
# 1985                                              BDS  12 years experience
# 1986   MBBS, MD - Dermatology , Venereology & Leprosy   8 years experience
#
#      Rating                        Place           Profile  \
# ...

# %% [markdown]
# Since the columns are filled with multiple data, we need to clean and separate the data first before doing eda.

# %%
#Qualification
train['Qualification']=train['Qualification'].str.split('-').str[0]
train['Qual1']=train['Qualification'].str.split(',').str[0]
train['Qual2']=train['Qualification'].str.split(',').str[1]
train['Qual3']=train['Qualification'].str.split(',').str[2]
train['Qual4']=train['Qualification'].str.split(',').str[3]
train['Qual5']=train['Qualification'].str.split(',').str[4]
train['Qual6']=train['Qualification'].str.split(',').str[5]
train.drop(['Qualification'],axis=1,inplace=True)
train
# Out:
#                Experience Rating                          Place  \
# 0     24 years experience   100%            Kakkanad, Ernakulam
# 1     12 years experience    98%          Whitefield, Bangalore
# 2      9 years experience    NaN     Mathikere - BEL, Bangalore
# 3     12 years experience    NaN   Bannerghatta Road, Bangalore
# 4     20 years experience   100%          Keelkattalai, Chennai
# ...                   ...    ...                            ...
# 5956  19 years experience    98%        Basavanagudi, Bangalore
# 5957  33 years experience    NaN          Nungambakkam, Chennai
# 5958  41 years experience    97%  Greater Kailash Part 2, Delhi
# 5959  15 years experience    90%         Vileparle West, Mumbai
# 5960  17 years experience   100%               Pitampura, Delhi
#
#                Profile                                 Miscellaneous_Info  \
# 0            Homeopath               100% 16 Feedback Kakkanad, Ernakulam
# ...

# %%
train['Qual4'].value_counts()
# Out:
#  MD                                      9
#  DNB                                     4
#  MS                                      3
#  UK)                                     3
#  Certification in Aesthetic Dentistry    2
#                                         ..
#  Certified Sinus lift surgeon            1
#  MSc                                     1
#  MSc                                     1
#  MDS                                     1
#  PGDMLS                                  1
# Name: Qual4, Length: 63, dtype: int64

# %%
#checking null values in qualifiation subdivisions
train.isnull().sum()
# Out:
# Experience               0
# Rating                3302
# Place                   25
# Profile                  0
# Miscellaneous_Info    2620
# Fees                     0
# Qual1                    0
# Qual2                 2500
# Qual3                 5511
# Qual4                 5879
# Qual5                 5937
# Qual6                 5954
# dtype: int64

# %%
a=['Qual1','Qual2','Qual3','Qual4',"Qual5",'Qual6']
for i in a:
    train[i].fillna('None',inplace=True)

# %%
for i in a:
    train[i]=train[i].replace(' ','')

# %%
for i in a:
    train[i]=train[i].str.lower()

# %%
train
# Out:
#                Experience Rating                          Place  \
# 0     24 years experience   100%            Kakkanad, Ernakulam
# 1     12 years experience    98%          Whitefield, Bangalore
# 2      9 years experience    NaN     Mathikere - BEL, Bangalore
# 3     12 years experience    NaN   Bannerghatta Road, Bangalore
# 4     20 years experience   100%          Keelkattalai, Chennai
# ...                   ...    ...                            ...
# 5956  19 years experience    98%        Basavanagudi, Bangalore
# 5957  33 years experience    NaN          Nungambakkam, Chennai
# 5958  41 years experience    97%  Greater Kailash Part 2, Delhi
# 5959  15 years experience    90%         Vileparle West, Mumbai
# 5960  17 years experience   100%               Pitampura, Delhi
#
#                Profile                                 Miscellaneous_Info  \
# 0            Homeopath               100% 16 Feedback Kakkanad, Ernakulam
# ...

# %%
#Qualification
test['Qualification']=test['Qualification'].str.split('-').str[0]
test['Qual1']=test['Qualification'].str.split(',').str[0]
test['Qual2']=test['Qualification'].str.split(',').str[1]
test['Qual3']=test['Qualification'].str.split(',').str[2]
test['Qual4']=test['Qualification'].str.split(',').str[3]
test['Qual5']=test['Qualification'].str.split(',').str[4]
test['Qual6']=test['Qualification'].str.split(',').str[5]
test.drop(['Qualification'],axis=1,inplace=True)
test
# Out:
#                Experience Rating                        Place  \
# 0     35 years experience    NaN       Ghatkopar East, Mumbai
# 1     31 years experience    NaN  West Marredpally, Hyderabad
# 2     40 years experience    70%            KK Nagar, Chennai
# 3      0 years experience    NaN       New Ashok Nagar, Delhi
# 4     16 years experience   100%    Kanakpura Road, Bangalore
# ...                   ...    ...                          ...
# 1982  10 years experience    NaN      Basavanagudi, Bangalore
# 1983   4 years experience    NaN             Choolai, Chennai
# 1984   9 years experience    NaN               Porur, Chennai
# 1985  12 years experience    98%           Arekere, Bangalore
# 1986   8 years experience    NaN        Pallikaranai, Chennai
#
#                Profile                                 Miscellaneous_Info  \
# 0     General Medicine                                                NaN
# ...

# %%
test['Qual6'].value_counts()
# Out:
#  MBA                            1
#  Fellowship in Diabetes (UK)    1
# Name: Qual6, dtype: int64

# %%
#checking null values in qualifiation subdivisions
test.isnull().sum()
# Out:
# Experience               0
# Rating                1090
# Place                    6
# Profile                  0
# Miscellaneous_Info     834
# Qual1                    0
# Qual2                  782
# Qual3                 1822
# Qual4                 1963
# Qual5                 1982
# Qual6                 1985
# dtype: int64

# %%
a=['Qual1','Qual2','Qual3','Qual4',"Qual5",'Qual6']
for i in a:
    test[i].fillna('None',inplace=True)

# %%
for i in a:
    test[i]=test[i].replace(' ','')

# %%
for i in a:
    test[i]=test[i].str.lower()

# %%
test.isnull().sum()
# Out:
# Experience               0
# Rating                1090
# Place                    6
# Profile                  0
# Miscellaneous_Info     834
# Qual1                    0
# Qual2                    0
# Qual3                    0
# Qual4                    0
# Qual5                    0
# Qual6                    0
# dtype: int64

# %% [markdown]
# Qual6 in train gives all null values where qual 7 in test set gives all null values. Thats why Qual 6 is included in train set to match with test set. This can later be dropped based on value counts. For now all Null values are replace with None. Now from Qual4 not much values are present in train or test data.

# %%
#Experience column division
train['Experience']=train['Experience'].str.split(' ').str[0]
train['Experience']=train['Experience'].astype(int)
train
# Out:
#       Experience Rating                          Place           Profile  \
# 0             24   100%            Kakkanad, Ernakulam         Homeopath
# 1             12    98%          Whitefield, Bangalore          Ayurveda
# 2              9    NaN     Mathikere - BEL, Bangalore    ENT Specialist
# 3             12    NaN   Bannerghatta Road, Bangalore          Ayurveda
# 4             20   100%          Keelkattalai, Chennai          Ayurveda
# ...          ...    ...                            ...               ...
# 5956          19    98%        Basavanagudi, Bangalore    ENT Specialist
# 5957          33    NaN          Nungambakkam, Chennai  General Medicine
# 5958          41    97%  Greater Kailash Part 2, Delhi  General Medicine
# 5959          15    90%         Vileparle West, Mumbai  General Medicine
# 5960          17   100%               Pitampura, Delhi           Dentist
#
#                                      Miscellaneous_Info  Fees Qual1  Qual2  \
# ...

# %%
#Experience column division
test['Experience']=test['Experience'].str.split(' ').str[0]
test['Experience']=test['Experience'].astype(int)
test
# Out:
#       Experience Rating                        Place           Profile  \
# 0             35    NaN       Ghatkopar East, Mumbai  General Medicine
# 1             31    NaN  West Marredpally, Hyderabad    ENT Specialist
# 2             40    70%            KK Nagar, Chennai    Dermatologists
# 3              0    NaN       New Ashok Nagar, Delhi          Ayurveda
# 4             16   100%    Kanakpura Road, Bangalore           Dentist
# ...          ...    ...                          ...               ...
# 1982          10    NaN      Basavanagudi, Bangalore          Ayurveda
# 1983           4    NaN             Choolai, Chennai    Dermatologists
# 1984           9    NaN               Porur, Chennai  General Medicine
# 1985          12    98%           Arekere, Bangalore           Dentist
# 1986           8    NaN        Pallikaranai, Chennai    Dermatologists
#
#                                      Miscellaneous_Info Qual1  \
# ...

# %% [markdown]
# The experience column is splitted to separate the number of years(numerical) and then the data is converted to int datatype.

# %%
#Rating column split
train['Rating'].fillna('0%',inplace=True)
train['Rating']=train['Rating'].str.split('%').str[0]
train['Rating']=train['Rating'].astype(int)
train['Rating']=train['Rating']/10
train
# Out:
#       Experience  Rating                          Place           Profile  \
# 0             24    10.0            Kakkanad, Ernakulam         Homeopath
# 1             12     9.8          Whitefield, Bangalore          Ayurveda
# 2              9     0.0     Mathikere - BEL, Bangalore    ENT Specialist
# 3             12     0.0   Bannerghatta Road, Bangalore          Ayurveda
# 4             20    10.0          Keelkattalai, Chennai          Ayurveda
# ...          ...     ...                            ...               ...
# 5956          19     9.8        Basavanagudi, Bangalore    ENT Specialist
# 5957          33     0.0          Nungambakkam, Chennai  General Medicine
# 5958          41     9.7  Greater Kailash Part 2, Delhi  General Medicine
# 5959          15     9.0         Vileparle West, Mumbai  General Medicine
# 5960          17    10.0               Pitampura, Delhi           Dentist
#
#                                      Miscellaneous_Info  Fees Qual1  Qual2  \
# ...

# %%
#Rating column split
test['Rating'].fillna('0%',inplace=True)
test['Rating']=test['Rating'].str.split('%').str[0]
test['Rating']=test['Rating'].astype(int)
test['Rating']=test['Rating']/10
test
# Out:
#       Experience  Rating                        Place           Profile  \
# 0             35     0.0       Ghatkopar East, Mumbai  General Medicine
# 1             31     0.0  West Marredpally, Hyderabad    ENT Specialist
# 2             40     7.0            KK Nagar, Chennai    Dermatologists
# 3              0     0.0       New Ashok Nagar, Delhi          Ayurveda
# 4             16    10.0    Kanakpura Road, Bangalore           Dentist
# ...          ...     ...                          ...               ...
# 1982          10     0.0      Basavanagudi, Bangalore          Ayurveda
# 1983           4     0.0             Choolai, Chennai    Dermatologists
# 1984           9     0.0               Porur, Chennai  General Medicine
# 1985          12     9.8           Arekere, Bangalore           Dentist
# 1986           8     0.0        Pallikaranai, Chennai    Dermatologists
#
#                                      Miscellaneous_Info Qual1  \
# ...

# %% [markdown]
# The null values in ratings are filled with 0%. Then the ratings string is split to generate the numerical value only which is then converted to integer and then divided by 10 to get the ratings format in a range of 0-10.

# %%
#Place reformat
train['Place'].fillna('None, None',inplace=True)
train['Area']=train['Place'].str.split(',').str[0]
train['City']=train['Place'].str.split(', ').str[1]
train.drop(['Place'],axis=1,inplace=True)
train
# Out:
#       Experience  Rating           Profile  \
# 0             24    10.0         Homeopath
# 1             12     9.8          Ayurveda
# 2              9     0.0    ENT Specialist
# 3             12     0.0          Ayurveda
# 4             20    10.0          Ayurveda
# ...          ...     ...               ...
# 5956          19     9.8    ENT Specialist
# 5957          33     0.0  General Medicine
# 5958          41     9.7  General Medicine
# 5959          15     9.0  General Medicine
# 5960          17    10.0           Dentist
#
#                                      Miscellaneous_Info  Fees Qual1  Qual2  \
# 0                  100% 16 Feedback Kakkanad, Ernakulam   100  bhms    md
# 1                 98% 76 Feedback Whitefield, Bangalore   350  bams    md
# 2                                                   NaN   300  mbbs    ms
# 3     Bannerghatta Road, Bangalore ₹250 Available on...   250  bsc    none
# ...

# %%
train['City'].value_counts()
# Out:
# Bangalore             1258
# Mumbai                1219
# Delhi                 1184
# Hyderabad              951
# Chennai                855
# Coimbatore             228
# Ernakulam              153
# Thiruvananthapuram      86
# None                    25
# Sector 5                 1
# Name: City, dtype: int64

# %%
train.isnull().sum()
# Out:
# Experience               0
# Rating                   0
# Profile                  0
# Miscellaneous_Info    2620
# Fees                     0
# Qual1                    0
# Qual2                    0
# Qual3                    0
# Qual4                    0
# Qual5                    0
# Qual6                    0
# Area                     0
# City                     1
# dtype: int64

# %%
train['City'].fillna('None',inplace=True)

# %%
#Place reformat
test['Place'].fillna('None, None',inplace=True)
test['Area']=test['Place'].str.split(',').str[0]
test['City']=test['Place'].str.split(', ').str[1]
test.drop(['Place'],axis=1,inplace=True)
test
# Out:
#       Experience  Rating           Profile  \
# 0             35     0.0  General Medicine
# 1             31     0.0    ENT Specialist
# 2             40     7.0    Dermatologists
# 3              0     0.0          Ayurveda
# 4             16    10.0           Dentist
# ...          ...     ...               ...
# 1982          10     0.0          Ayurveda
# 1983           4     0.0    Dermatologists
# 1984           9     0.0  General Medicine
# 1985          12     9.8           Dentist
# 1986           8     0.0    Dermatologists
#
#                                      Miscellaneous_Info Qual1  \
# 0                                                   NaN  mbbs
# 1                                                   NaN  mbbs
# 2                      70% 4 Feedback KK Nagar, Chennai  mbbs
# 3                                                   NaN  bams
# 4     General Dentistry Conservative Dentistry Cosme...   bds
# ...                                                 ...   ...
# ...

# %%
test.isnull().sum()
# Out:
# Experience              0
# Rating                  0
# Profile                 0
# Miscellaneous_Info    834
# Qual1                   0
# Qual2                   0
# Qual3                   0
# Qual4                   0
# Qual5                   0
# Qual6                   0
# Area                    0
# City                    0
# dtype: int64

# %% [markdown]
# PLace is divided into area and city and all null values are filled with None.

# %%
#checking Profile
train['Profile'].value_counts()
# Out:
# Dentist             1397
# General Medicine    1173
# Dermatologists      1034
# Homeopath            843
# Ayurveda             786
# ENT Specialist       728
# Name: Profile, dtype: int64

# %%
test['Profile'].value_counts()
# Out:
# General Medicine    444
# Dentist             441
# Dermatologists      339
# Homeopath           277
# Ayurveda            251
# ENT Specialist      235
# Name: Profile, dtype: int64

# %% [markdown]
# Profile column is okay

# %%
#Miscellaneous Column split
train['Miscellaneous_Info'].value_counts()
# Out:
# Acrylic Partial Denture Crowns and Bridges Fixing Artificial Teeth                      40
# Dental Fillings Zirconia Crowns Dental Implant Fixing                                   12
# Tooth Extraction Dental Fillings Scaling / Polishing                                    12
# Skin Allergy Treatment Skin Allergies Dermabrasion                                       9
# Skin Disease Treatment Kidney Stone Treatment Gall Bladder (Biliary) Stone Treatment     9
#                                                                                         ..
# 100% 13 Feedback Malviya Nagar, Delhi                                                    1
# 100% 23 Feedback Pitampura, Delhi                                                        1
# Dermaroller Acne / Pimples Treatment Scar Treatment                                      1
# 96% 19 Feedback Pitampura, Delhi                                                         1
# ...

# %% [markdown]
# The specialisation, fees, area, city and ratings provided at the miscellaneous column are already provided in other columns. SO only feedback count needs to be extracted.

# %%
#Miscellaneous split
train['Miscellaneous_Info'].fillna('% 0 Feedback',inplace=True)
train['Feedbacks']=train['Miscellaneous_Info'].str.split('% ').str[1]
train
# Out:
#       Experience  Rating           Profile  \
# 0             24    10.0         Homeopath
# 1             12     9.8          Ayurveda
# 2              9     0.0    ENT Specialist
# 3             12     0.0          Ayurveda
# 4             20    10.0          Ayurveda
# ...          ...     ...               ...
# 5956          19     9.8    ENT Specialist
# 5957          33     0.0  General Medicine
# 5958          41     9.7  General Medicine
# 5959          15     9.0  General Medicine
# 5960          17    10.0           Dentist
#
#                                      Miscellaneous_Info  Fees Qual1  Qual2  \
# 0                  100% 16 Feedback Kakkanad, Ernakulam   100  bhms    md
# 1                 98% 76 Feedback Whitefield, Bangalore   350  bams    md
# 2                                          % 0 Feedback   300  mbbs    ms
# 3     Bannerghatta Road, Bangalore ₹250 Available on...   250  bsc    none
# ...

# %%
train['Feedbacks'].value_counts()
# Out:
# 0 Feedback                                   2620
# 5 Feedback Malviya Nagar, Delhi                 3
# 1 Feedback Mulund West, Mumbai                  3
# 9 Feedback Whitefield, Bangalore                3
# 4 Feedback Bannerghatta Road, Bangalore         3
#                                              ...
# 35 Feedback Ramesh Nagar, Delhi                 1
# 10 Feedback Malleswaram, Bangalore              1
# 28 Feedback Hazrat Nizamuddin, Delhi            1
# 8 Feedback Koramangala 4 Block, Bangalore       1
# 42 Feedback KPHB, Hyderabad                     1
# Name: Feedbacks, Length: 1421, dtype: int64

# %%
train.isnull().sum()
# Out:
# Experience               0
# Rating                   0
# Profile                  0
# Miscellaneous_Info       0
# Fees                     0
# Qual1                    0
# Qual2                    0
# Qual3                    0
# Qual4                    0
# Qual5                    0
# Qual6                    0
# Area                     0
# City                     0
# Feedbacks             1834
# dtype: int64

# %%
train['Feedbacks']=train['Feedbacks'].str.split(' Feedback').str[0]
train
# Out:
#       Experience  Rating           Profile  \
# 0             24    10.0         Homeopath
# 1             12     9.8          Ayurveda
# 2              9     0.0    ENT Specialist
# 3             12     0.0          Ayurveda
# 4             20    10.0          Ayurveda
# ...          ...     ...               ...
# 5956          19     9.8    ENT Specialist
# 5957          33     0.0  General Medicine
# 5958          41     9.7  General Medicine
# 5959          15     9.0  General Medicine
# 5960          17    10.0           Dentist
#
#                                      Miscellaneous_Info  Fees Qual1  Qual2  \
# 0                  100% 16 Feedback Kakkanad, Ernakulam   100  bhms    md
# 1                 98% 76 Feedback Whitefield, Bangalore   350  bams    md
# 2                                          % 0 Feedback   300  mbbs    ms
# 3     Bannerghatta Road, Bangalore ₹250 Available on...   250  bsc    none
# ...

# %%
train['Feedbacks'].value_counts()
# Out:
# 0      2620
# 3        76
# 4        75
# 5        67
# 1        63
#        ...
# 203       1
# 113       1
# 179       1
# 130       1
# 162       1
# Name: Feedbacks, Length: 212, dtype: int64

# %%
train['Feedbacks'].fillna('0',inplace=True)
train
# Out:
#       Experience  Rating           Profile  \
# 0             24    10.0         Homeopath
# 1             12     9.8          Ayurveda
# 2              9     0.0    ENT Specialist
# 3             12     0.0          Ayurveda
# 4             20    10.0          Ayurveda
# ...          ...     ...               ...
# 5956          19     9.8    ENT Specialist
# 5957          33     0.0  General Medicine
# 5958          41     9.7  General Medicine
# 5959          15     9.0  General Medicine
# 5960          17    10.0           Dentist
#
#                                      Miscellaneous_Info  Fees Qual1  Qual2  \
# 0                  100% 16 Feedback Kakkanad, Ernakulam   100  bhms    md
# 1                 98% 76 Feedback Whitefield, Bangalore   350  bams    md
# 2                                          % 0 Feedback   300  mbbs    ms
# 3     Bannerghatta Road, Bangalore ₹250 Available on...   250  bsc    none
# ...

# %%
train['Feedbacks'].unique()
# Out:
# array(['16', '76', '0', '4', '14', '8', '7', '46', '6', '60', '18', '2',
#        '3', '21', '42', '65', '54', '43', '24', '44', '9', '47', '33',
#        '51', '23', '30', '13', '84', '15', '55', '112', '20', '1', '5',
#        '17', '67', '48', '11', '12', '40', '39', '57', '68', '175', '28',
#        '34', '29', '19', '10', '506', '62', '38', '116', '53', '99',
#        '566', '31', '72', '49', '50', '126', '22', '92', '59', '78',
#        '493', '147', '101', '444', '1061', '282', '213', '82', '181',
#        '187', '36', '71', '131', '159', '32', '141', '91', '153', '150',
#        '88', '83', '26', '80', '27', '45', '35', '560', '188', '94', '64',
#        'OFF* Available Today', '41', '37', '246', '109', '135', '52',
#        'OFF* Available on Fri, 08 Feb', '118', '547', '203', '372', '435',
#        '108', 'OFF*', '56', '66', '102', '63', '210', '180', '61', '120',
#        '128', '98', '854', '105', '96', '89', '25', '86', '74', '130',
# ...

# %%
z=['OFF* Available Today','OFF* Available on Fri, 08 Feb','Pitampura, Delhi','Nungambakkam, Chennai ₹500',', Mumbai ₹200','Khar West, Mumbai ₹2,000','OFF*']
for j in z:
    train['Feedbacks'].replace(j,'0',inplace=True)

# %%
train['Feedbacks'].unique()
# Out:
# array(['16', '76', '0', '4', '14', '8', '7', '46', '6', '60', '18', '2',
#        '3', '21', '42', '65', '54', '43', '24', '44', '9', '47', '33',
#        '51', '23', '30', '13', '84', '15', '55', '112', '20', '1', '5',
#        '17', '67', '48', '11', '12', '40', '39', '57', '68', '175', '28',
#        '34', '29', '19', '10', '506', '62', '38', '116', '53', '99',
#        '566', '31', '72', '49', '50', '126', '22', '92', '59', '78',
#        '493', '147', '101', '444', '1061', '282', '213', '82', '181',
#        '187', '36', '71', '131', '159', '32', '141', '91', '153', '150',
#        '88', '83', '26', '80', '27', '45', '35', '560', '188', '94', '64',
#        '41', '37', '246', '109', '135', '52', '118', '547', '203', '372',
#        '435', '108', '56', '66', '102', '63', '210', '180', '61', '120',
#        '128', '98', '854', '105', '96', '89', '25', '86', '74', '130',
#        '148', '332', '97', '185', '154', '343', '192', '152', '87', '178',
# ...

# %%
train['Feedbacks']=train['Feedbacks'].astype(int)
train
# Out:
#       Experience  Rating           Profile  \
# 0             24    10.0         Homeopath
# 1             12     9.8          Ayurveda
# 2              9     0.0    ENT Specialist
# 3             12     0.0          Ayurveda
# 4             20    10.0          Ayurveda
# ...          ...     ...               ...
# 5956          19     9.8    ENT Specialist
# 5957          33     0.0  General Medicine
# 5958          41     9.7  General Medicine
# 5959          15     9.0  General Medicine
# 5960          17    10.0           Dentist
#
#                                      Miscellaneous_Info  Fees Qual1  Qual2  \
# 0                  100% 16 Feedback Kakkanad, Ernakulam   100  bhms    md
# 1                 98% 76 Feedback Whitefield, Bangalore   350  bams    md
# 2                                          % 0 Feedback   300  mbbs    ms
# 3     Bannerghatta Road, Bangalore ₹250 Available on...   250  bsc    none
# ...

# %%
#Miscellaneous split
test['Miscellaneous_Info'].fillna('% 0 Feedback',inplace=True)
test['Feedbacks']=test['Miscellaneous_Info'].str.split('% ').str[1]
test
# Out:
#       Experience  Rating           Profile  \
# 0             35     0.0  General Medicine
# 1             31     0.0    ENT Specialist
# 2             40     7.0    Dermatologists
# 3              0     0.0          Ayurveda
# 4             16    10.0           Dentist
# ...          ...     ...               ...
# 1982          10     0.0          Ayurveda
# 1983           4     0.0    Dermatologists
# 1984           9     0.0  General Medicine
# 1985          12     9.8           Dentist
# 1986           8     0.0    Dermatologists
#
#                                      Miscellaneous_Info Qual1  \
# 0                                          % 0 Feedback  mbbs
# 1                                          % 0 Feedback  mbbs
# 2                      70% 4 Feedback KK Nagar, Chennai  mbbs
# 3                                          % 0 Feedback  bams
# 4     General Dentistry Conservative Dentistry Cosme...   bds
# ...                                                 ...   ...
# ...

# %%
test['Feedbacks']=test['Feedbacks'].str.split(' Feedback').str[0]
test
# Out:
#       Experience  Rating           Profile  \
# 0             35     0.0  General Medicine
# 1             31     0.0    ENT Specialist
# 2             40     7.0    Dermatologists
# 3              0     0.0          Ayurveda
# 4             16    10.0           Dentist
# ...          ...     ...               ...
# 1982          10     0.0          Ayurveda
# 1983           4     0.0    Dermatologists
# 1984           9     0.0  General Medicine
# 1985          12     9.8           Dentist
# 1986           8     0.0    Dermatologists
#
#                                      Miscellaneous_Info Qual1  \
# 0                                          % 0 Feedback  mbbs
# 1                                          % 0 Feedback  mbbs
# 2                      70% 4 Feedback KK Nagar, Chennai  mbbs
# 3                                          % 0 Feedback  bams
# 4     General Dentistry Conservative Dentistry Cosme...   bds
# ...                                                 ...   ...
# ...

# %%
test['Feedbacks'].fillna('0',inplace=True)
test
# Out:
#       Experience  Rating           Profile  \
# 0             35     0.0  General Medicine
# 1             31     0.0    ENT Specialist
# 2             40     7.0    Dermatologists
# 3              0     0.0          Ayurveda
# 4             16    10.0           Dentist
# ...          ...     ...               ...
# 1982          10     0.0          Ayurveda
# 1983           4     0.0    Dermatologists
# 1984           9     0.0  General Medicine
# 1985          12     9.8           Dentist
# 1986           8     0.0    Dermatologists
#
#                                      Miscellaneous_Info Qual1  \
# 0                                          % 0 Feedback  mbbs
# 1                                          % 0 Feedback  mbbs
# 2                      70% 4 Feedback KK Nagar, Chennai  mbbs
# 3                                          % 0 Feedback  bams
# 4     General Dentistry Conservative Dentistry Cosme...   bds
# ...                                                 ...   ...
# ...

# %%
test['Feedbacks'].unique()
# Out:
# array(['0', '4', '6', '203', '28', '9', '3', '10', '7', '91', '173',
#        '178', '1', '31', '29', '13', '112', '19', '59', '34', '111',
#        '158', '2', '11', '280', '41', '18', '87', '25', '5', '17', '53',
#        '8', '50', '170', '32', '143', '60', '14', '21', '62', '12', '16',
#        '23', '293', '97', '76', '77', '188', '71', '20', '591', '42',
#        '130', '260', '190', '95', '103', '98', '138', '30', '26', '24',
#        '79', '38', '45', '61', '44', '83', '43', '360', '33', '113',
#        '154', '72', '264', '201', '37', '68', '156', '75', '221', '67',
#        '127', '69', '22', '110', '330', '185', '251', '35', '159', '1987',
#        '115', '15', '230', '55', 'Angamaly, Ernakulam ₹150', '125', '119',
#        '207', '70', '89', '435', '39', '104', '164', '106', '136', '140',
#        '73', '165', '149', '40', '100', '51', '128', '172', '57', '94',
#        '340', '145', '390', '80', '200', '174', '144', '296', '52', '102',
# ...

# %%
test['Feedbacks'].replace('Angamaly, Ernakulam ₹150','0',inplace=True)
test['Feedbacks']=test['Feedbacks'].astype(int)
test
# Out:
#       Experience  Rating           Profile  \
# 0             35     0.0  General Medicine
# 1             31     0.0    ENT Specialist
# 2             40     7.0    Dermatologists
# 3              0     0.0          Ayurveda
# 4             16    10.0           Dentist
# ...          ...     ...               ...
# 1982          10     0.0          Ayurveda
# 1983           4     0.0    Dermatologists
# 1984           9     0.0  General Medicine
# 1985          12     9.8           Dentist
# 1986           8     0.0    Dermatologists
#
#                                      Miscellaneous_Info Qual1  \
# 0                                          % 0 Feedback  mbbs
# 1                                          % 0 Feedback  mbbs
# 2                      70% 4 Feedback KK Nagar, Chennai  mbbs
# 3                                          % 0 Feedback  bams
# 4     General Dentistry Conservative Dentistry Cosme...   bds
# ...                                                 ...   ...
# ...

# %%
train.drop(['Miscellaneous_Info'],axis=1,inplace=True)

# %%
test.drop(['Miscellaneous_Info'],axis=1,inplace=True)

# %%
train
# Out:
#       Experience  Rating           Profile  Fees Qual1  Qual2 Qual3 Qual4  \
# 0             24    10.0         Homeopath   100  bhms    md   none  none
# 1             12     9.8          Ayurveda   350  bams    md   none  none
# 2              9     0.0    ENT Specialist   300  mbbs    ms   none  none
# 3             12     0.0          Ayurveda   250  bsc    none  none  none
# 4             20    10.0          Ayurveda   250  bams   none  none  none
# ...          ...     ...               ...   ...   ...    ...   ...   ...
# 5956          19     9.8    ENT Specialist   300  mbbs    ms   none  none
# 5957          33     0.0  General Medicine   100  mbbs   none  none  none
# 5958          41     9.7  General Medicine   600  mbbs   none  none  none
# 5959          15     9.0  General Medicine   100  mbbs    md   none  none
# 5960          17    10.0           Dentist   200   bds   mds   none  none
#
#      Qual5 Qual6                    Area       City  Feedbacks
# ...

# %%
test
# Out:
#       Experience  Rating           Profile Qual1  \
# 0             35     0.0  General Medicine  mbbs
# 1             31     0.0    ENT Specialist  mbbs
# 2             40     7.0    Dermatologists  mbbs
# 3              0     0.0          Ayurveda  bams
# 4             16    10.0           Dentist   bds
# ...          ...     ...               ...   ...
# 1982          10     0.0          Ayurveda  bams
# 1983           4     0.0    Dermatologists   md
# 1984           9     0.0  General Medicine  mbbs
# 1985          12     9.8           Dentist   bds
# 1986           8     0.0    Dermatologists  mbbs
#
#                                       Qual2 Qual3 Qual4 Qual5 Qual6  \
# 0                                      none  none  none  none  none
# 1      diploma in otorhinolaryngology (dlo)  none  none  none  none
# 2                                      ddvl  none  none  none  none
# 3                                      none  none  none  none  none
# ...

# %% [markdown]
# For the miscellaneous info column, all null values are filled with % 0 Feedback. Then the strings are separated taking % and Feedback as separators. The remaining not interger values are directly replaced with 0. Then the whole string is changed to int datatype

# %%
#Checking Null Values
train.isnull().sum()
# Out:
# Experience    0
# Rating        0
# Profile       0
# Fees          0
# Qual1         0
# Qual2         0
# Qual3         0
# Qual4         0
# Qual5         0
# Qual6         0
# Area          0
# City          0
# Feedbacks     0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Experience    0
# Rating        0
# Profile       0
# Qual1         0
# Qual2         0
# Qual3         0
# Qual4         0
# Qual5         0
# Qual6         0
# Area          0
# City          0
# Feedbacks     0
# dtype: int64

# %%
train.dtypes
# Out:
# Experience      int32
# Rating        float64
# Profile        object
# Fees            int64
# Qual1          object
# Qual2          object
# Qual3          object
# Qual4          object
# Qual5          object
# Qual6          object
# Area           object
# City           object
# Feedbacks       int32
# dtype: object

# %%
test.dtypes
# Out:
# Experience      int32
# Rating        float64
# Profile        object
# Qual1          object
# Qual2          object
# Qual3          object
# Qual4          object
# Qual5          object
# Qual6          object
# Area           object
# City           object
# Feedbacks       int32
# dtype: object

# %%
#Using Label Encoder
c=['Profile','Qual1','Qual2','Qual3','Qual4','Qual5','Qual6','Area','City']
import sklearn
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for j in c:
    train[j]=le.fit_transform(train[j].astype(str))
train
# Out:
#       Experience  Rating  Profile  Fees  Qual1  Qual2  Qual3  Qual4  Qual5  \
# 0             24    10.0        5   100      8    198    162     63     24
# 1             12     9.8        0   350      5    198    162     63     24
# 2              9     0.0        3   300     70    217    162     63     24
# 3             12     0.0        0   250     12    280    162     63     24
# 4             20    10.0        0   250      5    280    162     63     24
# ...          ...     ...      ...   ...    ...    ...    ...    ...    ...
# 5956          19     9.8        3   300     70    217    162     63     24
# 5957          33     0.0        4   100     70    280    162     63     24
# 5958          41     9.7        4   600     70    280    162     63     24
# 5959          15     9.0        4   100     70    198    162     63     24
# 5960          17    10.0        1   200      6    201    162     63     24
#
#       Qual6  Area  City  Feedbacks
# ...

# %%
for j in c:
    test[j]=le.fit_transform(test[j].astype(str))
test
# Out:
#       Experience  Rating  Profile  Qual1  Qual2  Qual3  Qual4  Qual5  Qual6  \
# 0             35     0.0        4     40    160     83     20      5      2
# 1             31     0.0        3     40     54     83     20      5      2
# 2             40     7.0        2     40     28     83     20      5      2
# 3              0     0.0        0      1    160     83     20      5      2
# 4             16    10.0        1      2    114     83     20      5      2
# ...          ...     ...      ...    ...    ...    ...    ...    ...    ...
# 1982          10     0.0        0      1     66     83     20      5      2
# 1983           4     0.0        2     42    160     83     20      5      2
# 1984           9     0.0        4     40    112     83     20      5      2
# 1985          12     9.8        1      2    160     83     20      5      2
# 1986           8     0.0        2     40    110     83     20      5      2
#
#       Area  City  Feedbacks
# ...

# %%
train.describe()
# Out:
#         Experience       Rating      Profile         Fees        Qual1  \
# count  5961.000000  5961.000000  5961.000000  5961.000000  5961.000000
# mean     17.303976     4.221725     2.441872   307.944640    41.099312
# std      11.142798     4.734093     1.658014   190.920373    31.938913
# min       0.000000     0.000000     0.000000     5.000000     0.000000
# 25%       9.000000     0.000000     1.000000   150.000000     6.000000
# 50%      14.000000     0.000000     2.000000   300.000000    70.000000
# 75%      23.000000     9.600000     4.000000   500.000000    70.000000
# max      66.000000    10.000000     5.000000   950.000000    98.000000
#
#              Qual2        Qual3        Qual4        Qual5        Qual6  \
# count  5961.000000  5961.000000  5961.000000  5961.000000  5961.000000
# mean    215.430632   156.308338    62.594699    23.949673     5.996645
# std      72.347729    22.843064     4.021311     0.905326     0.124197
# ...

# %%
test.describe()
# Out:
#         Experience       Rating      Profile        Qual1        Qual2  \
# count  1987.000000  1987.000000  1987.000000  1987.000000  1987.000000
# mean     17.874685     4.263412     2.508807    23.472068   119.928032
# std      11.366764     4.728401     1.654223    18.979944    42.131996
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       9.000000     0.000000     1.000000     2.000000   110.000000
# 50%      15.000000     0.000000     2.000000    40.000000   119.000000
# 75%      24.000000     9.600000     4.000000    40.000000   160.000000
# max      65.000000    10.000000     5.000000    51.000000   160.000000
#
#              Qual3        Qual4        Qual5        Qual6         Area  \
# count  1987.000000  1987.000000  1987.000000  1987.000000  1987.000000
# mean     79.985405    19.878712     4.992451     1.998490   289.648213
# std      11.581677     1.261357     0.166243     0.050153   173.263142
# ...

# %% [markdown]
# Since most of the values are generated, skewness and outliers would be present. They are not treated to maintain the volumn of the dataset

# %%
train.corr()
# Out:
#             Experience    Rating   Profile      Fees     Qual1     Qual2  \
# Experience    1.000000  0.055327  0.169388  0.032032  0.185847 -0.132937
# Rating        0.055327  1.000000 -0.126389  0.171828 -0.010842 -0.134979
# Profile       0.169388 -0.126389  1.000000  0.137032  0.341394 -0.029506
# Fees          0.032032  0.171828  0.137032  1.000000  0.227772 -0.158972
# Qual1         0.185847 -0.010842  0.341394  0.227772  1.000000 -0.225865
# Qual2        -0.132937 -0.134979 -0.029506 -0.158972 -0.225865  1.000000
# Qual3        -0.038840 -0.072640 -0.011953 -0.042662 -0.052658  0.385818
# Qual4        -0.000756 -0.045110  0.002833 -0.020325  0.010950  0.159611
# Qual5        -0.009306 -0.026013  0.008334 -0.029086  0.010391  0.087802
# Qual6        -0.009428 -0.023076 -0.001762  0.000252 -0.008968  0.028768
# Area          0.000791 -0.041175  0.018170 -0.055000  0.003435  0.012640
# City         -0.007507 -0.105611 -0.019082 -0.106655 -0.033500  0.064395
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(train.corr(),annot=True)

# %% [markdown]
# no significant correlation found

# %%
for i in train.columns:
    plt.figure()
    train[i].plot(kind='hist')

# %%
for i in train.columns:
    plt.figure()
    sns.lineplot(i,'Fees',data=train)

# %%
for i in train.columns:
    plt.figure()
    sns.regplot(i,'Fees',data=train)

# %% [markdown]
# Fees increases with increase in experience, rating an profile category. Fees increases with increases in qual1 category and decreases with increase in qual2,3,4,5,6 categories. Fees decreases with increase in city category. fees increases with increase in feedbacks.

# %%
#skewness treatment
for i in train.columns:
    if train.skew().loc[i]>0.55:
        train[i]=train[i].apply(lambda x:np.log(x+1))

# %%
#skewness treatment
for i in test.columns:
    if test.skew().loc[i]>0.55:
        test[i]=test[i].apply(lambda x:np.log(x+1))

# %%
#X Y division of dataset
x=train.drop(['Fees'],axis=1)
y=train['Fees']
y=y.values.reshape(-1,1)
y.shape
# Out:
# (5961, 1)

# %%
#Scaling data
import sklearn
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
dx=scale.fit_transform(x)
x=pd.DataFrame(dx,columns=x.columns)

# %%
#Scaling data-test
dt=scale.fit_transform(test)
test=pd.DataFrame(dt,columns=test.columns)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.externals import joblib

# %%
#Calculating best r score
def max_score(model):
    max_score=0
    for r_state in range(42,100):
        xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=r_state,test_size=0.20)
        model.fit(xtrain,ytrain)
        ypred=model.predict(xtest)
        r2=r2_score(ytest,ypred)
        if r2>max_score:
            max_score=r2
            final_r_state=r_state
    print(max_score,'is max accuracy against r_state',final_r_state)

# %%
lr=LinearRegression()
max_score(lr)
# Out:
# 0.14258337279050715 is max accuracy against r_state 44

# %%
alpha={'alpha':[.0001,.001,.01,.1,1,10]}
grid=GridSearchCV(estimator=Ridge(),param_grid=alpha)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'alpha': 10}

# %%
rd=Ridge(alpha=10)
max_score(rd)
# Out:
# 0.1425108076333077 is max accuracy against r_state 44

# %%
from sklearn.svm import SVR
para={'kernel':['rbf','linear','poly']}
grid=GridSearchCV(estimator=SVR(),param_grid=para)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'kernel': 'rbf'}

# %%
svr=SVR(kernel='rbf')
max_score(svr)
# Out:
# 0.19416115401668588 is max accuracy against r_state 44

# %%
import xgboost
from xgboost import XGBRegressor

# %%
xgbr=XGBRegressor()
max_score(xgbr)
# Out:
# 0.23610830467766764 is max accuracy against r_state 79

# %%
alpha={'alpha':[.0001,.001,.01,.1,1,10]}
grid1=GridSearchCV(estimator=Lasso(),param_grid=alpha)
grid1.fit(x,y)
print(grid1.best_params_)
# Out:
# {'alpha': 0.001}

# %%
ls=Lasso(alpha=0.001)
max_score(ls)
# Out:
# 0.14194030258691337 is max accuracy against r_state 44

# %%
alpha={'alpha':[.0001,.001,.01,.1,1,10]}
grid=GridSearchCV(estimator=ElasticNet(),param_grid=alpha)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'alpha': 0.01}

# %%
en=ElasticNet(alpha=0.01)
max_score(en)
# Out:
# 0.1387792880946166 is max accuracy against r_state 44

# %%
from sklearn.neighbors import KNeighborsRegressor
#Knr
n_neighbors={'n_neighbors':[2,3,4,5,6,7,8,9]}
grid=GridSearchCV(estimator=KNeighborsRegressor(),param_grid=n_neighbors)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'n_neighbors': 9}

# %%
knr=KNeighborsRegressor(n_neighbors=9)
max_score(knr)
# Out:
# 0.1590021681875431 is max accuracy against r_state 63

# %%
from sklearn.tree import DecisionTreeRegressor
para={'criterion':['mse','mae','friedman_mse']}
grid=GridSearchCV(estimator=DecisionTreeRegressor(),param_grid=para)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'criterion': 'mae'}

# %%
dtr=DecisionTreeRegressor(criterion='mae')

# %%
from sklearn.ensemble import GradientBoostingRegressor
para={'n_estimators':[100,200,300,500],'learning_rate':[1,0.1,0.01,0.001]}
grid=GridSearchCV(estimator=GradientBoostingRegressor(),param_grid=para)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'learning_rate': 0.1, 'n_estimators': 300}

# %%
gdr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=300)
max_score(gdr)
# Out:
# 0.2583626690241033 is max accuracy against r_state 63

# %%
from sklearn.ensemble import RandomForestRegressor
para={'n_estimators':[100,200,300,500]}
grid=GridSearchCV(estimator=RandomForestRegressor(),param_grid=para)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'n_estimators': 500}

# %%
rfr=RandomForestRegressor(n_estimators=500,criterion='mse')
max_score(rfr)
# Out:
# 0.2291762940061235 is max accuracy against r_state 79

# %%
models=[]
models.append(('Linear Regression',lr,44))
models.append(('Lasso Regression',ls,44))
models.append(('Ridge regression',rd,44))
models.append(('Elastic Net',en,44))
models.append(('Support Vector Regressor',svr,44))
models.append(('KNeighborsRegressor',knr,63))
models.append(('DecisionTreeRegressor',dtr,44))
models.append(('XGBoostRegressor',xgbr,79))
models.append(('GradientBoostingRegressor',gdr,63))
models.append(('RandomForestRegressor',rfr,79))

Model=[]
R2Score=[]
Cvs=[]
MAE=[]
MSE=[]
RMSE=[]

# %%
for name,model,randomstate in models:
    print('***********',name,'************')
    print('\n')
    Model.append(name)
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=randomstate,test_size=0.20)
    model.fit(xtrain,ytrain)
    print(model)
    pred=model.predict(xtest)
    print('\n')
    R2=r2_score(ytest,pred)
    print('R2 score=',R2)
    R2Score.append(R2*100)
    print('\n')
    cvs=cross_val_score(model,x,y,cv=5,scoring='r2').mean()
    print('Cross Validation Score=',cvs)
    Cvs.append(cvs)
    print('\n')
    mae=mean_absolute_error(ytest,pred)
    print('Mean Absolute Error=',mae)
    MAE.append(mae)
    print('\n')
    mse=mean_squared_error(ytest,pred)
    print("Mean Squared Error=",mse)
    MSE.append(mse)
    print('\n')
    rmse=np.sqrt(mean_squared_error(ytest,pred))
    print('Root Mean Squared Error=',rmse)
    RMSE.append(rmse)
# Out:
# *********** Linear Regression ************
#
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
#
# R2 score= 0.14258337279050715
#
#
# Cross Validation Score= 0.10404697206491362
#
#
# Mean Absolute Error= 0.5234308171282794
#
#
# Mean Squared Error= 0.3955885474164824
#
#
# Root Mean Squared Error= 0.6289583034005374
# *********** Lasso Regression ************
#
#
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)
#
#
# R2 score= 0.14194030258691337
#
#
# Cross Validation Score= 0.10424120747735363
#
#
# Mean Absolute Error= 0.5236792935111441
#
#
# Mean Squared Error= 0.39588524239492534
#
#
# Root Mean Squared Error= 0.629194121392536
# *********** Ridge regression ************
#
#
# Ridge(alpha=10, copy_X=True, fit_intercept=True, max_iter=None, normalize=False,
# ...

# %%
Result=pd.DataFrame({'Model':Model,'R2_Score':R2Score,'Cross Validation Score':Cvs,'Mean Absolute Error':MAE,'Mean Squared Error':MSE,'Root Mean Squared Error':RMSE})
Result
# Out:
#                        Model   R2_Score  Cross Validation Score  \
# 0          Linear Regression  14.258337                0.104047
# 1           Lasso Regression  14.194030                0.104241
# 2           Ridge regression  14.251081                0.104069
# 3                Elastic Net  13.877929                0.104253
# 4   Support Vector Regressor  19.416115                0.129620
# 5        KNeighborsRegressor  15.900217                0.095157
# 6      DecisionTreeRegressor -36.255283               -0.468377
# 7           XGBoostRegressor  23.610830                0.194057
# 8  GradientBoostingRegressor  25.700012                0.226734
# 9      RandomForestRegressor  22.419883                0.183522
#
#    Mean Absolute Error  Mean Squared Error  Root Mean Squared Error
# 0             0.523431            0.395589                 0.628958
# 1             0.523679            0.395885                 0.629194
# ...

# %% [markdown]
# All models show extreme poor performance mainly due to too much manipulation of dataset.Gdr is selected.

# %%
#saving the model
joblib.dump(gdr,'gdr.doctor.obj')
# Out:
# ['gdr.doctor.obj']

# %%
#Loading the data
GDR=joblib.load('gdr.doctor.obj')

# %%
#prediction
GDR.fit(x,y)
prediction=GDR.predict(test)
print(prediction)
# Out:
# [5.24081407 5.38336405 5.65075812 ... 5.71107693 5.28444721 5.67701603]

# %%
test['Pred']=prediction
test
# Out:
#       Experience    Rating   Profile     Qual1     Qual2     Qual3     Qual4  \
# 0       1.225280 -0.901887  0.901673  0.871030  0.951345  0.260356  0.096181
# 1       1.054884 -0.901887  0.297007  0.871030 -1.565191  0.260356  0.096181
# 2       1.413428  0.578901 -0.307658  0.871030 -2.182455  0.260356  0.096181
# 3      -3.958980 -0.901887 -1.516990 -1.184288  0.951345  0.260356  0.096181
# 4       0.139817  1.213525 -0.912324 -1.131588 -0.140737  0.260356  0.096181
# ...          ...       ...       ...       ...       ...       ...       ...
# 1982   -0.489956 -0.901887 -1.516990 -1.184288 -1.280300  0.260356  0.096181
# 1983   -1.630614 -0.901887 -0.307658  0.976430  0.951345  0.260356  0.096181
# 1984   -0.627841 -0.901887  0.901673  0.871030 -0.188219  0.260356  0.096181
# 1985   -0.248280  1.171216 -0.912324 -1.131588  0.951345  0.260356  0.096181
# 1986   -0.780265 -0.901887 -0.307658  0.871030 -0.235700  0.260356  0.096181
#
# ...
