# %%
#Importing libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing dataset
data_train=pd.read_csv("C:/Users/DC/Downloads/Data_Train.csv")
train=pd.DataFrame(data_train)
train
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 12685        QUICK BITES          13228
# 12686  CASUAL DINING,BAR           9686
# 12687             LOUNGE          11133
# 12688      CASUAL DINING           6134
# 12689      CASUAL DINING           6430
#
#                                                CUISINES  \
# 0                           Malwani, Goan, North Indian
# 1                        Asian, Modern Indian, Japanese
# 2            North Indian, Chinese, Biryani, Hyderabadi
# 3                                      Tibetan, Chinese
# 4                                              Desserts
# ...                                                 ...
# 12685                       North Indian, Burger, Kebab
# ...

# %%
#Importing dataset
data_test=pd.read_csv("C:/Users/DC/Downloads/Data_Test.csv")
test=pd.DataFrame(data_test)
test
# Out:
#               TITLE  RESTAURANT_ID  \
# 0     CASUAL DINING           4085
# 1       QUICK BITES          12680
# 2     CASUAL DINING           1411
# 3              None            204
# 4       QUICK BITES          13453
# ...             ...            ...
# 4226  CASUAL DINING           9057
# 4227           None           1247
# 4228    QUICK BITES           8617
# 4229    QUICK BITES           6485
# 4230    QUICK BITES           2421
#
#                                            CUISINES  \
# 0             North Indian, Chinese, Mughlai, Kebab
# 1      South Indian, Fast Food, Pizza, North Indian
# 2           North Indian, Seafood, Biryani, Chinese
# 3                                           Biryani
# 4                              South Indian, Kerala
# ...                                             ...
# 4226                 North Indian, Mughlai, Chinese
# 4227  Biryani, North Indian, Sandwich, Salad, Wraps
# 4228                      Continental, North Indian
# ...

# %%
train.dtypes
# Out:
# TITLE            object
# RESTAURANT_ID     int64
# CUISINES         object
# TIME             object
# CITY             object
# LOCALITY         object
# RATING           object
# VOTES            object
# COST              int64
# dtype: object

# %%
test.dtypes
# Out:
# TITLE            object
# RESTAURANT_ID     int64
# CUISINES         object
# TIME             object
# CITY             object
# LOCALITY         object
# RATING           object
# VOTES            object
# dtype: object

# %%
#Cleaning title
train['TITLE1']=train['TITLE'].str.split(',').str[0]
train['TITLE2']=train['TITLE'].str.split(',').str[1]
train['TITLE3']=train['TITLE'].str.split(',').str[2]
train['TITLE']=train.drop(['TITLE'],axis=1)
train
# Out:
#        TITLE  RESTAURANT_ID                                          CUISINES  \
# 0       9438           9438                       Malwani, Goan, North Indian
# 1      13198          13198                    Asian, Modern Indian, Japanese
# 2      10915          10915        North Indian, Chinese, Biryani, Hyderabadi
# 3       6346           6346                                  Tibetan, Chinese
# 4      15387          15387                                          Desserts
# ...      ...            ...                                               ...
# 12685  13228          13228                       North Indian, Burger, Kebab
# 12686   9686           9686                                 Goan, Continental
# 12687  11133          11133          Finger Food, Continental, Asian, Chinese
# 12688   6134           6134  North Indian, South Indian, Chinese, Street Food
# 12689   6430           6430                             North Indian, Chinese
#
# ...

# %%
train['TITLE3'].unique()
# Out:
# array([nan])

# %%
#title 3 has all nan values so it can be dropped
train.drop(['TITLE3'],axis=1,inplace=True)

# %%
train['TITLE2'].value_counts()
# Out:
# BAR               428
# QUICK BITES       261
# CASUAL DINING     257
# DESSERT PARLOR    138
# CAFÉ               94
# BAKERY             69
# SWEET SHOP         53
# LOUNGE             47
# PUB                35
# BEVERAGE SHOP      34
# MICROBREWERY       27
# FOOD COURT         15
# FINE DINING         8
# CLUB                5
# KIOSK               4
# IRANI CAFE          3
# CONFECTIONERY       2
# FOOD TRUCK          1
# PAAN SHOP           1
# Name: TITLE2, dtype: int64

# %% [markdown]
# Title 2 has around 90 percent nan values. It will be dropped to reduce skewness of data.

# %%
train.isnull().sum()
# Out:
# TITLE                0
# RESTAURANT_ID        0
# CUISINES             0
# TIME                 0
# CITY               112
# LOCALITY            98
# RATING               2
# VOTES             1204
# COST                 0
# TITLE1               0
# TITLE2           11208
# dtype: int64

# %%
train.drop(['TITLE2'],axis=1,inplace=True)

# %%
train['TITLE1']=train['TITLE1'].str.upper()
train['TITLE1']=train['TITLE1'].str.replace(' ','')

# %%
#Cleaning title
test['TITLE1']=test['TITLE'].str.split(',').str[0]
test.drop(['TITLE'],axis=1,inplace=True)

# %%
test
# Out:
#       RESTAURANT_ID                                       CUISINES  \
# 0              4085          North Indian, Chinese, Mughlai, Kebab
# 1             12680   South Indian, Fast Food, Pizza, North Indian
# 2              1411        North Indian, Seafood, Biryani, Chinese
# 3               204                                        Biryani
# 4             13453                           South Indian, Kerala
# ...             ...                                            ...
# 4226           9057                 North Indian, Mughlai, Chinese
# 4227           1247  Biryani, North Indian, Sandwich, Salad, Wraps
# 4228           8617                      Continental, North Indian
# 4229           6485                               Rolls, Beverages
# 4230           2421                                        Mughlai
#
#                                                    TIME         CITY  \
# 0                         12noon – 12midnight (Mon-Sun)        Noida
# ...

# %%
test.isnull().sum()
# Out:
# RESTAURANT_ID      0
# CUISINES           0
# TIME               0
# CITY              35
# LOCALITY          30
# RATING             2
# VOTES            402
# TITLE1             0
# dtype: int64

# %%
test['TITLE1']=test['TITLE1'].str.upper()
test['TITLE1']=test['TITLE1'].str.replace(' ','')

# %%
#Cleaning cuisines
train['CUISINE1']=train['CUISINES'].str.split(',').str[0]
train['CUISINE2']=train['CUISINES'].str.split(',').str[1]
train['CUISINE3']=train['CUISINES'].str.split(',').str[2]
train['CUISINES']=train.drop(['CUISINES'],axis=1)
train
# Out:
#        TITLE  RESTAURANT_ID CUISINES  \
# 0       9438           9438     9438
# 1      13198          13198    13198
# 2      10915          10915    10915
# 3       6346           6346     6346
# 4      15387          15387    15387
# ...      ...            ...      ...
# 12685  13228          13228    13228
# 12686   9686           9686     9686
# 12687  11133          11133    11133
# 12688   6134           6134     6134
# 12689   6430           6430     6430
#
#                                                    TIME         CITY  \
# 0                11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)        Thane
# 1                                  6pm – 11pm (Mon-Sun)      Chennai
# 2                   11am – 3:30pm, 7pm – 11pm (Mon-Sun)      Chennai
# 3                               11:30am – 1am (Mon-Sun)       Mumbai
# 4                                  11am – 1am (Mon-Sun)       Mumbai
# ...                                                 ...          ...
# ...

# %%
train.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY              112
# LOCALITY           98
# RATING              2
# VOTES            1204
# COST                0
# TITLE1              0
# CUISINE1            0
# CUISINE2         3062
# CUISINE3         6999
# dtype: int64

# %% [markdown]
# Cuisines3 has more tha 50% null values.So it can be dropped.

# %%
train.drop(['CUISINE3'],axis=1,inplace=True)

# %%
train['CUISINE1']=train['CUISINE1'].str.replace(' ','')
train['CUISINE2']=train['CUISINE2'].str.replace(' ','')

# %%
train['CUISINE1']=train['CUISINE1'].str.upper()
train['CUISINE2']=train['CUISINE2'].str.upper()

# %%
train['CUISINE2']=train['CUISINE2'].fillna('NONE')

# %%
#Cleaning cuisines
test['CUISINE1']=test['CUISINES'].str.split(',').str[0]
test['CUISINE2']=test['CUISINES'].str.split(',').str[1]
test['CUISINES']=test.drop(['CUISINES'],axis=1)
test
# Out:
#       RESTAURANT_ID CUISINES  \
# 0              4085     4085
# 1             12680    12680
# 2              1411     1411
# 3               204      204
# 4             13453    13453
# ...             ...      ...
# 4226           9057     9057
# 4227           1247     1247
# 4228           8617     8617
# 4229           6485     6485
# 4230           2421     2421
#
#                                                    TIME         CITY  \
# 0                         12noon – 12midnight (Mon-Sun)        Noida
# 1                               7am – 12:30AM (Mon-Sun)       Mumbai
# 2                              11am – 11:30pm (Mon-Sun)       Mumbai
# 3     9am – 10pm (Mon, Wed, Thu, Fri, Sat, Sun), 10:...    Faridabad
# 4                                 11am – 10pm (Mon-Sun)        Kochi
# ...                                                 ...          ...
# 4226                        11:30am – 11:30pm (Mon-Sun)    New Delhi
# ...

# %%
test['CUISINE1']=test['CUISINE1'].str.replace(' ','')
test['CUISINE2']=test['CUISINE2'].str.replace(' ','')

# %%
test['CUISINE1']=test['CUISINE1'].str.upper()
test['CUISINE2']=test['CUISINE2'].str.upper()

# %%
test['CUISINE2']=test['CUISINE2'].fillna('NONE')

# %%
#cleaning Votes
train['VOTES'].fillna('0 votes',inplace=True)
train['VOTES']=train['VOTES'].str.split(' ').str[0]
train['VOTES']=train['VOTES'].astype(int)
train
# Out:
#        TITLE  RESTAURANT_ID CUISINES  \
# 0       9438           9438     9438
# 1      13198          13198    13198
# 2      10915          10915    10915
# 3       6346           6346     6346
# 4      15387          15387    15387
# ...      ...            ...      ...
# 12685  13228          13228    13228
# 12686   9686           9686     9686
# 12687  11133          11133    11133
# 12688   6134           6134     6134
# 12689   6430           6430     6430
#
#                                                    TIME         CITY  \
# 0                11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)        Thane
# 1                                  6pm – 11pm (Mon-Sun)      Chennai
# 2                   11am – 3:30pm, 7pm – 11pm (Mon-Sun)      Chennai
# 3                               11:30am – 1am (Mon-Sun)       Mumbai
# 4                                  11am – 1am (Mon-Sun)       Mumbai
# ...                                                 ...          ...
# ...

# %%
#cleaning Votes
test['VOTES'].fillna('0 votes',inplace=True)
test['VOTES']=test['VOTES'].str.split(' ').str[0]
test['VOTES']=test['VOTES'].astype(int)
test
# Out:
#       RESTAURANT_ID CUISINES  \
# 0              4085     4085
# 1             12680    12680
# 2              1411     1411
# 3               204      204
# 4             13453    13453
# ...             ...      ...
# 4226           9057     9057
# 4227           1247     1247
# 4228           8617     8617
# 4229           6485     6485
# 4230           2421     2421
#
#                                                    TIME         CITY  \
# 0                         12noon – 12midnight (Mon-Sun)        Noida
# 1                               7am – 12:30AM (Mon-Sun)       Mumbai
# 2                              11am – 11:30pm (Mon-Sun)       Mumbai
# 3     9am – 10pm (Mon, Wed, Thu, Fri, Sat, Sun), 10:...    Faridabad
# 4                                 11am – 10pm (Mon-Sun)        Kochi
# ...                                                 ...          ...
# 4226                        11:30am – 11:30pm (Mon-Sun)    New Delhi
# ...

# %%
test.isnull().sum()
# Out:
# RESTAURANT_ID     0
# CUISINES          0
# TIME              0
# CITY             35
# LOCALITY         30
# RATING            2
# VOTES             0
# TITLE1            0
# CUISINE1          0
# CUISINE2          0
# dtype: int64

# %%
train.dropna(inplace=True)

# %%
test.dropna(inplace=True)

# %%
train
# Out:
#        TITLE  RESTAURANT_ID CUISINES  \
# 0       9438           9438     9438
# 1      13198          13198    13198
# 2      10915          10915    10915
# 3       6346           6346     6346
# 4      15387          15387    15387
# ...      ...            ...      ...
# 12685  13228          13228    13228
# 12686   9686           9686     9686
# 12687  11133          11133    11133
# 12688   6134           6134     6134
# 12689   6430           6430     6430
#
#                                                    TIME         CITY  \
# 0                11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)        Thane
# 1                                  6pm – 11pm (Mon-Sun)      Chennai
# 2                   11am – 3:30pm, 7pm – 11pm (Mon-Sun)      Chennai
# 3                               11:30am – 1am (Mon-Sun)       Mumbai
# 4                                  11am – 1am (Mon-Sun)       Mumbai
# ...                                                 ...          ...
# ...

# %%
train.drop(['TITLE'],axis=1,inplace=True)
train.drop(['CUISINES'],axis=1,inplace=True)
train
# Out:
#        RESTAURANT_ID                                              TIME  \
# 0               9438            11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)
# 1              13198                              6pm – 11pm (Mon-Sun)
# 2              10915               11am – 3:30pm, 7pm – 11pm (Mon-Sun)
# 3               6346                           11:30am – 1am (Mon-Sun)
# 4              15387                              11am – 1am (Mon-Sun)
# ...              ...                                               ...
# 12685          13228  12noon – 12midnight (Mon, Tue, Wed, Thu, Sun)...
# 12686           9686   12noon – 1am (Mon-Fri),11am – 5pm, 7pm – 1am...
# 12687          11133                        12noon – 12:30AM (Mon-Sun)
# 12688           6134                           6am – 10:45pm (Mon-Sun)
# 12689           6430                          12:30pm – 11pm (Mon-Sun)
#
#               CITY              LOCALITY RATING  VOTES  COST         TITLE1  \
# ...

# %%
test.drop(['CUISINES'],axis=1,inplace=True)
test
# Out:
#       RESTAURANT_ID                                               TIME  \
# 0              4085                      12noon – 12midnight (Mon-Sun)
# 1             12680                            7am – 12:30AM (Mon-Sun)
# 2              1411                           11am – 11:30pm (Mon-Sun)
# 3               204  9am – 10pm (Mon, Wed, Thu, Fri, Sat, Sun), 10:...
# 4             13453                              11am – 10pm (Mon-Sun)
# ...             ...                                                ...
# 4226           9057                        11:30am – 11:30pm (Mon-Sun)
# 4227           1247                               11am – 1am (Mon-Sun)
# 4228           8617                         9:30am – 10:30pm (Mon-Sun)
# 4229           6485  11am – 11:30pm (Mon, Tue, Wed, Thu, Sat, Sun),...
# 4230           2421                                5pm – 1am (Mon-Sun)
#
#              CITY          LOCALITY RATING  VOTES        TITLE1     CUISINE1  \
# ...

# %%
train.drop(['TIME'],axis=1,inplace=True)
test.drop(['TIME'],axis=1,inplace=True)

# %%
train['CITY'].unique()
# Out:
# array(['Thane', 'Chennai', 'Mumbai', 'Bangalore', 'Gurgaon', 'Hyderabad',
#        'Kochi', 'Thane West', 'Andheri Lokhandwala', 'New Delhi',
#        'Andheri West', 'Malad East', '682036', 'Bangalor', 'Navi Mumbai',
#        'Bandra West', 'Delhi', 'Noida', 'Bangalore-560066',
#        'Secunderabad', 'India', 'Madhuranagar', 'Chennai Teynampet',
#        'Faridabad', 'Chembur.', 'Maharashtra', 'opp gurudwara Shakurpur',
#        'Telagana Land Line:040-48507016', 'Ghaziabad', 'Karnataka',
#        'Kerala', 'Edappally', 'Kadavanthra', 'Ernakulam Circle kochi',
#        'Bengalore', 'Near Reliance Fresh', 'Kilpauk', 'Bengaluru',
#        'Kothaguda', 'Goregaon West', 'Banglore', 'Tamil Nadu', 'Kakkanad',
#        'Kochi Elamkulam', 'Outer Ring Road', 'Mulund East',
#        'Secunderabad main road near signal NMREC COLLEGE', 'Telangana',
#        'Ponnuruni Kochi', 'Gachibowli', 'Semmancheri',
#        '5th Main Teachers Colony Koramangala Block 1 Bangalore 560034',
# ...

# %%
train['CITY'].replace(['Bangalor','Bangalore-560066','Bengalore','Bengaluru','Banglore',
   '5th Main Teachers Colony Koramangala Block 1 Bangalore 560034',
   'BTM Layout','JP Nagar Bangalore','Whitefield Bangalore','Thammenahalli Village',
   'Bangalore - 560076','Bangalore.','Rajiv gandhi Nagar','Brigade Road',
   'Banaswadi (Next to Indian Bank) Bangalore','BTM Bangalore','Near Jyothinivas College',
   'Bangalore Koramangala 7th Block','bangalore : 560085','IOB Bank Kamala Nagar',
   'CPR layout harlur main road opposite to ozone ever green apartment Bangalore -',
   'Karnataka 560043','Bangalore - 560103','Banglaore','HBR Layout','Near Munrshwara Temple', 'Off Brigade Road',
   'Kanakapura Road Banglore','BTM 1st Stage','Marathahalli','B-1 Stage',
   'Bangalore land mark above mahaveer hard ware','Phase 1 Bangalore',
   'Bangalore 560076','Bangalore Road','Karnataka','Karnataka 560103',
   'SG Palya','Karnataka 560102','Karnataka 560037', 'B.B.M.P East (Karnataka) - 560049','Adjacent To Commercial Street',
   'Malleshwaram Bangalore', 'Kadubesanahalli Bangalore','Near Reliance Fresh','Vijaya Nagar','Sarjapur','MG Road',
   'Mahadevpura','NEW BEL ROAD 560054','JP Nagar','Rajarajeshwari Nagar bangalore','Hosur Road',
   'Ulsoo','1st Tavarekere','Thanisandra','Indiranagar','HSR Layout','1st Stage'],'Bangalore',inplace=True)

# %%
train['CITY'].replace(['Chennai Teynampet','Tamil Nadu','Besant Nagar','Arumbakkam chennai-600106.',
    'Avadi', 'Velachery','Pallavaram','Chennai 600034.','Chennai - 600040', 'Perungudi',
    'Chennai Padur', 'Medavakkam', 'Chennai Kovalam', 'Chennai opp: Vasanth & co',  
    'Mogappair. Chennai', 'Chennai Perungudi', 'Chennai Thuraipakkam', 'OMR Karapakkam',
    'Chennai Thousand Lights',  'Chennai- 600107', 'ECR NEELANKARAI Chennai 600115',
    'Chennai.', 'Chennai (Bang Opposite Indian Bank)','Chennai Opposite 5C Bus stand', 
    'Mahabalipuram', 'Chennai Mahabalipuram', 'Nungambakkam','Chennai-40',
    'East Coast Road (ECR)', 'Ramapuram', 'Chennai Chrompet','Nandanam','Thiruvanmiyur', 
    'Ambattur','Chennai - 34 Landmark - Near Loyola College', 'Anna Nagar West', 
    'Anna Salai','Chenn ai', 'Perambur', 'Vadapalani','Palavakkam','Sholinganallur',
    'Mogappair', 'Ashok Nagar', 'Chennai. (Near Hotel Matshya)',  'Chromepet','Sathya Nagar','Andavar Nagar','3rd Street',
    'chennai','Tambaram','Vadapalani', 'Anna Nagar East','Kilpauk','Potheri','Nallala Street','Nallathambi Main Road','ward X11',
    'GST Road', 'Vadapalani.','Semmancheri','Dewan Rama Road','Navallur','Kolathur','First Street'],'Chennai',inplace=True)

# %%
train['CITY'].replace(['Telagana Land Line:040-48507016', 'Telangana','Gachibowli','Kondapur', 'Madhapur',
    'Hyderabad Behind Vacs Pastries','Hyderabad neerus emporium.', 'Hitech City','Kothaguda',
    'Telangana 500003','Hyderabad.', 'Telangana 500034','Telangana 500032','Madhuranagar','Outer Ring Road',
'Champapet','TCS Synergy park' ,'Hyderabad-500032','Near Santosh Banjara Hyderabad','Gachibowli Hyderabad','Masab Tank',
    'hyderabad', 'Telengana','Telangana 500081','Kondapur.',  'Telangana 500070','Uppal', 
    'Nizampet','Ramanthapur','Serilingampally','Begumpet Hyderabad','Hyderabad Manikonda',
    'Jubilee Hills','Mehdipatnam','Behind Ramalayam Temple', 'Narayanguda','Maharaja Hotel Beside Gardania Bar','Attapur.','Near Bharat Petroleum.', 'Sriram nagar',
    'Metro Pillar No 21. Mettuguda main road near railway degree college.','Gandipet','Begumpet','Lahari Apartments','ECIL','Lingampally','Dilsukhnagar','Road 3',
    'Manikonda','West Maredpally','Banjara Hills','Himayath Nagar','Beside Excellency Gardens','Kukatapally','Kukatpally'],'Hyderabad',inplace=True)

# %%
train['CITY'].replace(['Kerala', 'Edappally','Ernakulam Circle kochi','Kochi Elamkulam','Ponnuruni Kochi', 
    'Kochi Vyttila', 'Kochi Palarivattom','Ernakulam', 'Kochi Chullickal','Kadavanthra',
    'Kochi-683101','p.o Kochi','Kerala 683104','Kerala 682013','Kochi.','Tripunithura',
    'MALAPALLIPURAM P .O THRISSUR','Kochi Ravipuram', 'Kerala 690525','Kochi-18',
    'MG Road Ernakulam','Kochi Kakkanad', 'Kochi International Airport VIP Road', 'Mig Housing Society','Pallimukku', 'Elamakkara','Panampilly Nagar',
    'Kerala 682001 India', 'Kerala 683585', 'Kerala 682304','Fort Kochi','kochi','aluva circle','682035.','Thykoodam','chullickal','Kalamassery',
    'Kochi Aluva 102', 'Kerala 682024', 'Kochi','Kakkanad','Kaloor','Palarivattom','Kochi-16','682036','Marine Drive','Thevera','Perumbavoor',
    'Veliaveetil house Vivekananda Nagar Elamakkara','Trivandrum','Nedumbassery','Aluva', 'Aluva Circle','Vyttila'],'Kochi',inplace=True)

# %%
train['CITY'].replace(['Secunderabad', 'Secunderabad main road near signal NMREC COLLEGE','Khairatabad',
    'Secunderabad ECIL','Secunderabad. WE HAVE NO BRANCHES.','Secunderabad.'],'Secunderabad',inplace=True)

# %%
train['CITY'].replace(['Mumbai','Navi Mumbai','Mumbai Mahim','Navi Mumbai.', 'Mumbai - 400007','Naya Nagar Mira Road',
    'Mumbai.','Mumbai Andheri East','Mumbai Dombivali East','navi mumbai','Chembur.','Borivali East.','Borivali West',
    'Mumbai - 400013','West Mumbai','Andheri west Mumbai','Mumbai Chakala','Borivali West.','Mulund west','Vasai west',
    'BK Guda', 'Jogeshwari (w) Mumbai','Mumbai - 80','East Mumbai','Navi-Mumbai','Powai (Next to Powai Plaza)','opp mukteshwar ashram powai','Pokhran Road 2',
    'Mumbai This is a Delivery & Take-away Restaurant only.','Thane Mumbai','Goregaon West','Mulund East','Bandra W','Vasai West.','Kalyan West',
    'Khar Mumbai','Andheri Lokhandwala','Andheri West','Andheri Lokhandwala.','Dombivali East','Kandivali','Malad East','Near Shangrilla Bus Stop',
    'Lower Parel West','Badlapur West.','khar west','Mira raod east','Kalyan','Palm Beach Road','Lower Parel','Bhayandar','Rajanpada','Khar (west)','Mahim',
    'Thane','Thane West','Thane (W)','Maharashtra','Maharashtra 400102','Bandra West','Powai','Grant Road West','Wagle Estate'],'Mumbai',inplace=True)

# %%
train['CITY'].replace(['New Delhi','Delhi','Delhi NCR','Chander Nagar New Delhi','New Delhi.',
    'New Delhi-110024','Greater Kailash 2 New Delhi','opp gurudwara Shakurpur','Ghaziabad','Dwarka',
    'Amrit kaur market opposite new delhi railway station paharganj','Uttar Pradesh','Haryana',
    'PVR plaza cinema building Connaught Place','Vaishali Ghaziabad', 'Block F', 'Opposite Barathi Gas Company',
    'Delhi 110085','Old Delhi','New Delhi..Near by SBI bank','New Delhi 110075','Janakpuri','India','Virar West','Ashok Vihar Phase 1',
    'Faridabad','Faridabd', 'Rohini','6 & 7 - 4/64 Subhash Nagar','Near Ramlila Ground','Old Railway Road','Pitampura','Citypark','Naharpar',
    'Dist. Center New Delhi','Gurugram','Sector 7 Dwarka','10th avenue','Haridwar Apartments','Saket', 'Indirapuram','Karol Bagh'],'Delhi',inplace=True)

# %%
train['CITY'].replace(['Gurgaon','Gurgoan','Gurgaon Haryana India','Gurgaon Haryana','Golf Course Road','DLF Galleria','Sector 51','Rodeo Drive Sector 49'],'Gurgaon',inplace=True)

# %%
train['CITY'].replace(['Noida','Sector 51 Noida','Greater Noida','Near Sector 110 Noida','Sector 1'],'Noida',inplace=True)

# %%
train['CITY'].unique()
# Out:
# array(['Mumbai', 'Chennai', 'Bangalore', 'Gurgaon', 'Hyderabad', 'Kochi',
#        'Delhi', 'Noida', 'Secunderabad'], dtype=object)

# %%
train
# Out:
#        RESTAURANT_ID       CITY              LOCALITY RATING  VOTES  COST  \
# 0               9438     Mumbai        Dombivali East    3.6     49  1200
# 1              13198    Chennai             Ramapuram    4.2     30  1500
# 2              10915    Chennai            Saligramam    3.8    221   800
# 3               6346     Mumbai           Bandra West    4.1     24   800
# 4              15387     Mumbai           Lower Parel    3.8    165   300
# ...              ...        ...                   ...    ...    ...   ...
# 12685          13228  Hyderabad            Gachibowli    3.8    546   500
# 12686           9686     Mumbai  Bandra Kurla Complex    4.3   1214  1800
# 12687          11133     Mumbai                 Vashi    4.0    608  1300
# 12688           6134    Chennai           Maduravoyal    3.5     32   400
# 12689           6430  Hyderabad       Vanasthalipuram    3.4    677   600
#
#               TITLE1     CUISINE1      CUISINE2
# ...

# %%
test['CITY'].unique()
# Out:
# array(['Noida', 'Mumbai', 'Faridabad', 'Kochi', 'Hyderabad',
#        'Navi Mumbai', 'Chennai', 'New Delhi', 'Bangalore', 'Vasai Mumbai',
#        'Gurgaon', 'Palarivattom', 'Delhi', 'Ernakulam', 'Thane West',
#        'Ghaziabad', 'Chennai.', 'Thane', 'Telangana', 'Bandra West',
#        'Potheri', 'Panathur Main Road', 'Secunderabad', 'JP Nagar',
#        'Near Andheri West Station',
#        'opposite to western side of ITPL Service gate', 'Kalkaji',
#        'Bengaluru', 'APR Chambers', 'Tamil Nadu 600102', 'Andheri West',
#        'India', 'Serilingampally', 'Maharashtra.', 'Gandhinagar Rd',
#        'Near Andheri East Station', 'HSR Layout', 'Greater Noida',
#        'Uttar Pradesh', 'Dwarka', 'Velachery', 'Anna Nagar West',
#        'Indiranagar', 'Whitefield', 'Kochi Ravipuram', 'Kerala 682036',
#        'Madhapur', 'Hyderabad.', 'Mira Road Thane Mumbai',
#        'India Gate New Delhi', 'Bangalore - 560095', '1st Stage',
# ...

# %%
test['CITY'].replace(['Bangalor','Bangalore-560066','Bengalore','Bengaluru','Banglore',
   '5th Main Teachers Colony Koramangala Block 1 Bangalore 560034',
   'BTM Layout','JP Nagar Bangalore','Whitefield Bangalore','Thammenahalli Village',
   'Bangalore - 560076','Bangalore.','Rajiv gandhi Nagar','Brigade Road','Church Street',
   'Banaswadi (Next to Indian Bank) Bangalore','BTM Bangalore','Near Jyothinivas College',
   'Bangalore Koramangala 7th Block','bangalore : 560085','IOB Bank Kamala Nagar',
   'CPR layout harlur main road opposite to ozone ever green apartment Bangalore -',
   'Karnataka 560043','Bangalore - 560103','Banglaore','HBR Layout','Near Munrshwara Temple', 'Off Brigade Road',
   'Kanakapura Road Banglore','BTM 1st Stage','Marathahalli','B-1 Stage','BTM',
   'Bangalore land mark above mahaveer hard ware','Phase 1 Bangalore','Tavarekere Main Road',
   'Bangalore 560076','Bangalore Road','Karnataka','Karnataka 560103','Sahakara Nagar',
    'opposite to western side of ITPL Service gate','Bangalore - 560095','Panathur Main Road','Whitefield',
   'SG Palya','Karnataka 560102','Karnataka 560037', 'B.B.M.P East (Karnataka) - 560049','Adjacent To Commercial Street',
   'Malleshwaram Bangalore', 'Kadubesanahalli Bangalore','Near Reliance Fresh','Vijaya Nagar','Sarjapur','MG Road',
   'Mahadevpura','NEW BEL ROAD 560054','JP Nagar','Rajarajeshwari Nagar bangalore','Hosur Road',
   'Ulsoo','1st Tavarekere','Thanisandra','Indiranagar','HSR Layout','1st Stage'],'Bangalore',inplace=True)

# %%
test['CITY'].replace(['Chennai Teynampet','Tamil Nadu','Besant Nagar','Arumbakkam chennai-600106.',
    'Avadi', 'Velachery','Pallavaram','Chennai 600034.','Chennai - 600040', 'Perungudi',
    'Chennai Padur', 'Medavakkam', 'Chennai Kovalam', 'Chennai opp: Vasanth & co',  
    'Mogappair. Chennai', 'Chennai Perungudi', 'Chennai Thuraipakkam', 'OMR Karapakkam',
    'Chennai Thousand Lights',  'Chennai- 600107', 'ECR NEELANKARAI Chennai 600115','Chepauk',
    'Chennai.', 'Chennai (Bang Opposite Indian Bank)','Chennai Opposite 5C Bus stand', 'MM Nagar',
    'Mahabalipuram', 'Chennai Mahabalipuram', 'Nungambakkam','Chennai-40','Vandalur','Kaaraikudi Complex',
    'East Coast Road (ECR)', 'Ramapuram', 'Chennai Chrompet','Nandanam','Thiruvanmiyur', 'RA Puram','Alwarpet',
    'Ambattur','Chennai - 34 Landmark - Near Loyola College', 'Anna Nagar West', 'Thiruvanmiyur (Opp Eurokids LB Road)',
    'Anna Salai','Chenn ai', 'Perambur', 'Vadapalani','Palavakkam','Sholinganallur',
    'Mogappair', 'Ashok Nagar', 'Chennai. (Near Hotel Matshya)',  'Chromepet','Sathya Nagar','Andavar Nagar','3rd Street',
    'chennai','Tambaram','Vadapalani', 'Anna Nagar East','Kilpauk','Potheri','Nallala Street',
                      'Nallathambi Main Road','ward X11','Tamil Nadu 600102','Balavinayagar Nagar Chennai',
    'Chennai - 600018','chennai-119','Chenna','Chennai Injambakkam','T-Nagar Chennai','Chennai-600008','Chennai Velachery',
'Chennai 600040','Chennai 40','Chennai (Above Bombay Brasserie)', 'Chennai 37','Sholinganallur. Chennai',
    'GST Road', 'Vadapalani.','Semmancheri','Dewan Rama Road','Navallur','Kolathur','First Street'],'Chennai',inplace=True)

# %%
test['CITY'].replace(['Telagana Land Line:040-48507016', 'Telangana','Gachibowli','Kondapur', 'Madhapur',
    'Hyderabad Behind Vacs Pastries','Hyderabad neerus emporium.', 'Hitech City','Kothaguda',
    'Telangana 500003','Hyderabad.', 'Telangana 500034','Telangana 500032','Madhuranagar','Outer Ring Road',
'Champapet','TCS Synergy park' ,'Hyderabad-500032','Near Santosh Banjara Hyderabad','Gachibowli Hyderabad','Masab Tank',
    'hyderabad', 'Telengana','Telangana 500081','Kondapur.',  'Telangana 500070','Uppal', 
    'Nizampet','Ramanthapur','Serilingampally','Begumpet Hyderabad','Hyderabad Manikonda',
    'Jubilee Hills','Mehdipatnam','Behind Ramalayam Temple', 'Narayanguda','Maharaja Hotel Beside Gardania Bar',
                      'Attapur.','Near Bharat Petroleum.', 'Sriram nagar','Nallagandla',
    'Metro Pillar No 21. Mettuguda main road near railway degree college.','Gandipet','Begumpet',
'Lahari Apartments','ECIL','Lingampally','Dilsukhnagar','Road 3','Forum Sujana Mall Opposite to Malaysian township',
    'Vanasthalipuram', 'Habsiguda','Yousufguda','Old Hafeezpet','Suraram','Tolichowki',
    'Hyderabad.Star hypermarket opposite side Service road','Telangana 500027','Hyderaba','Mehdipatnam Hyderabad',
    'Manikonda','West Maredpally','Banjara Hills','Himayath Nagar','Beside Excellency Gardens',
                      'Kukatapally','Kukatpally'],'Hyderabad',inplace=True)

# %%
test['CITY'].replace(['Secunderabad', 'Secunderabad main road near signal NMREC COLLEGE','Khairatabad','Secunderbad',
    'Secunderabad ECIL','Secunderabad. WE HAVE NO BRANCHES.','Secunderabad.'],'Secunderabad',inplace=True)

# %%
test['CITY'].replace(['Kerala', 'Edappally','Ernakulam Circle kochi','Kochi Elamkulam','Ponnuruni Kochi', 
    'Kochi Vyttila', 'Kochi Palarivattom','Ernakulam', 'Kochi Chullickal','Kadavanthra',
    'Kochi-683101','p.o Kochi','Kerala 683104','Kerala 682013','Kochi.','Tripunithura',
    'MALAPALLIPURAM P .O THRISSUR','Kochi Ravipuram', 'Kerala 690525','Kochi-18',
    'MG Road Ernakulam','Kochi Kakkanad', 'Kochi International Airport VIP Road', 'Mig Housing Society',
                      'Pallimukku', 'Elamakkara','Panampilly Nagar',
    'Kerala 682001 India', 'Kerala 683585', 'Kerala 682304','Fort Kochi','kochi','aluva circle','682035.',
                      'Thykoodam','chullickal','Kalamassery',
    'Kochi Aluva 102', 'Kerala 682024', 'Kochi','Kakkanad','Kaloor','Palarivattom','Kochi-16','682036',
                      'Marine Drive','Thevera','Perumbavoor','Shihab Thangal Road',
    'Kerala 682021','Kerala 682305', '682024','Kerala 682036','Kochi Panampilly Nagar','Kerala 682015', 'Kerala 682018',
'Kerala 682305','Kerala 682022','Kerala 682028','Chittethukkara','KK Road',
    'Veliaveetil house Vivekananda Nagar Elamakkara','Trivandrum','Nedumbassery',
                      'Aluva', 'Aluva Circle','Vyttila'],'Kochi',inplace=True)

# %%
test['CITY'].replace(['Mumbai','Navi Mumbai','Mumbai Mahim','Navi Mumbai.', 'Mumbai - 400007','Naya Nagar Mira Road',
    'Mumbai.','Mumbai Andheri East','Mumbai Dombivali East','navi mumbai','Chembur.','Borivali East.','Borivali West',
    'Mumbai - 400013','West Mumbai','Andheri west Mumbai','Mumbai Chakala','Borivali West.','Mulund west','Vasai west',
    'BK Guda', 'Jogeshwari (w) Mumbai','Mumbai - 80','East Mumbai','Navi-Mumbai','Powai (Next to Powai Plaza)',
                      'opp mukteshwar ashram powai','Pokhran Road 2',
    'Mumbai This is a Delivery & Take-away Restaurant only.','Thane Mumbai','Goregaon West','Mulund East',
                      'Bandra W','Vasai West.','Kalyan West','Forum Sujana Mall Opposite to Malaysian township','Virar Mumbai',
                      'Kandivali West',
    'Khar Mumbai','Andheri Lokhandwala','Andheri West','Andheri Lokhandwala.','Dombivali East',
                      'Kandivali','Malad East','Near Shangrilla Bus Stop',
    'Lower Parel West','Badlapur West.','khar west','Mira raod east','Kalyan','Palm Beach Road','Lower Parel',
                      'Bhayandar','Rajanpada','Khar (west)','Mahim','Mulund West','Opposite Ellora Building',
    'Thane','Thane West','Thane (W)','Maharashtra','Maharashtra 400102','Bandra West','Powai',
    'Near Andheri West Station','Borivali (W) Mumbai: 400 092.', 'Mumbai Mumbra','Vasai Mumbai','Near Andheri West Station',
'Kurla Mumbai','Miumbai','Jogeshwari West Mumbai','Mumbai Ulhasnagar','Mohammad Ali Road Mumbai','Thane West Thane West',
'Kurla (W)','Mumbai 400015','Mumbai Veera Desai Area','Mumbai 400015','Girgaum','Dombivli','Chowpatty',
'Near Andheri East Station','Maharashtra.','Maharashtra 400092','Mira Road Thane Mumbai','Mumbai 400070',
                      'Grant Road West','Wagle Estate'],'Mumbai',inplace=True)

# %%
test['CITY'].replace(['New Delhi','Delhi','Delhi NCR','Chander Nagar New Delhi','New Delhi.',
    'New Delhi-110024','Greater Kailash 2 New Delhi','opp gurudwara Shakurpur','Ghaziabad','Dwarka',
    'Amrit kaur market opposite new delhi railway station paharganj','Uttar Pradesh','Haryana',
    'PVR plaza cinema building Connaught Place','Vaishali Ghaziabad', 'Block F', 'Opposite Barathi Gas Company',
    'Delhi 110085','Old Delhi','New Delhi..Near by SBI bank','New Delhi 110075','Janakpuri','India','Virar West',
    'Ashok Vihar Phase 1','Faridabad','Faridabd', 'Rohini','6 & 7 - 4/64 Subhash Nagar','Near Ramlila Ground',
    'Old Railway Road', 'Pitampura','Citypark','Naharpar','Kalkaji','APR Chambers','Gandhinagar Rd','Marad',
    'Greater Kailash 1 (GK 1) New Delhi','New Delhi 110011','Delh.','Greater Kailash 1 (GK 1) New Delhi','India Gate New Delhi',
    'Dist. Center New Delhi','Gurugram','Sector 7 Dwarka','10th avenue','Haridwar Apartments','Saket',
                      'Community Centre','Indirapuram','Karol Bagh'],'Delhi',inplace=True)

# %%
test['CITY'].replace(['Gurgaon','Gurgoan','Gurgaon Haryana India','Gurgaon Haryana','Golf Course Road',
                      'DLF Galleria','Sector 51','Rodeo Drive Sector 49'],'Gurgaon',inplace=True)

# %%
test['CITY'].replace(['Noida','Sector 51 Noida','Greater Noida','Near Sector 110 Noida','Sector 1',
                      'Sector-6 Noida 201301','Near Sector 34','Noida Extention'],'Noida',inplace=True)

# %%
test['CITY'].unique()
# Out:
# array(['Noida', 'Mumbai', 'Delhi', 'Kochi', 'Hyderabad', 'Chennai',
#        'Bangalore', 'Gurgaon', 'Secunderabad'], dtype=object)

# %%
#Location
train['LOCALITY'].unique()
# Out:
# array(['Dombivali East', 'Ramapuram', 'Saligramam', ..., 'Market Road',
#        'Near Perambur', 'Near Malviya Nagar'], dtype=object)

# %%
test['LOCALITY'].unique()
# Out:
# array(['Sector 18', 'Grant Road', 'Marine Lines', 'NIT', 'Kaloor',
#        'Banjara Hills', 'Kharghar', 'Navalur', 'IP Extension',
#        'Palarivattom', 'Electronic City', 'West Mambalam', 'Worli',
#        'Ulsoor', 'Abids', 'MG Road', 'Dahisar West', 'Vijay Nagar',
#        'Fort', 'Anna Salai', 'East', 'DLF Phase 4', 'Banaswadi',
#        'Jubilee Hills', 'Sector 15', 'BTM', 'Elamkulam', 'Bandra West',
#        'Aluva', 'Indiranagar', 'Marol', 'Whitefield', 'Fort Kochi',
#        'Film Nagar', 'Edappally', 'Bandra Kurla Complex', 'Marathahalli',
#        'Dombivali East', 'N.W.A Punjabi Bagh', 'Kodambakkam',
#        'Anna Nagar West', 'Sarjapur Road', 'Tripunithura', 'Matunga East',
#        'Kathrikadavu', 'Mylapore', 'Kakkanad', 'Malakpet',
#        'Kandivali West', 'Sector 31', 'Kalyan East', 'Necklace Road',
#        'Sector 49', 'Miyapur', 'Ashok Nagar', 'Aerocity', 'Purasavakkam',
#        'Srinagar Colony', 'Madhapur', 'Kalyan', 'Subhash Nagar',
# ...

# %%
train['LOCALITY']=train['LOCALITY'].str.lower()
test['LOCALITY']=test['LOCALITY'].str.lower()

# %%
train.isnull().sum()
# Out:
# RESTAURANT_ID    0
# CITY             0
# LOCALITY         0
# RATING           0
# VOTES            0
# COST             0
# TITLE1           0
# CUISINE1         0
# CUISINE2         0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# RESTAURANT_ID    0
# CITY             0
# LOCALITY         0
# RATING           0
# VOTES            0
# TITLE1           0
# CUISINE1         0
# CUISINE2         0
# dtype: int64

# %%
train.dtypes
# Out:
# RESTAURANT_ID     int64
# CITY             object
# LOCALITY         object
# RATING           object
# VOTES             int32
# COST              int64
# TITLE1           object
# CUISINE1         object
# CUISINE2         object
# dtype: object

# %%
train['RATING'].unique()
# Out:
# array(['3.6', '4.2', '3.8', '4.1', '4.0', '4.3', '3.9', '3.3', '3.4', '-',
#        '4.5', '3.5', '4.4', '2.7', '3.7', '4.7', 'NEW', '3.1', '2.5',
#        '4.6', '2.8', '3.0', '3.2', '2.6', '2.9', '4.9', '4.8', '2.4',
#        '2.3', '2.0', '2.1', '2.2'], dtype=object)

# %%
test['RATING'].unique()
# Out:
# array(['4.3', '4.2', '3.8', '3.6', '3.7', 'NEW', '4.0', '3.4', '3.2',
#        '4.1', '3.0', '-', '3.5', '4.5', '3.9', '3.3', '2.9', '3.1', '2.5',
#        '2.8', '4.6', '4.4', '2.7', '4.8', '2.6', '4.9', '2.1', '4.7',
#        '2.3', '2.4', '2.2'], dtype=object)

# %%
train['RATING'].replace(['-','NEW'],'0',inplace=True)
test['RATING'].replace(['-','NEW'],'0',inplace=True)

# %%
train['RATING']=train['RATING'].astype(float)
test['RATING']=test['RATING'].astype(float)

# %%
train.dtypes
# Out:
# RESTAURANT_ID      int64
# CITY              object
# LOCALITY          object
# RATING           float64
# VOTES              int32
# COST               int64
# TITLE1            object
# CUISINE1          object
# CUISINE2          object
# dtype: object

# %%
#labelEncoder
import sklearn
from sklearn.preprocessing import LabelEncoder
a=['CITY','LOCALITY','TITLE1','CUISINE1','CUISINE2']
le=LabelEncoder()
for i in a:
    train[i]=le.fit_transform(train[i].astype(str))
train
# Out:
#        RESTAURANT_ID  CITY  LOCALITY  RATING  VOTES  COST  TITLE1  CUISINE1  \
# 0               9438     6       279     3.6     49  1200       4        59
# 1              13198     1      1035     4.2     30  1500       4         6
# 2              10915     1      1090     3.8    221   800       4        72
# 3               6346     6       127     4.1     24   800      21       100
# 4              15387     6       613     3.8    165   300       8        28
# ...              ...   ...       ...     ...    ...   ...     ...       ...
# 12685          13228     4       333     3.8    546   500      21        72
# 12686           9686     6       124     4.3   1214  1800       4        37
# 12687          11133     6      1335     4.0    608  1300      14        34
# 12688           6134     1       619     3.5     32   400       4        72
# 12689           6430     4      1326     3.4    677   600       4        72
#
#        CUISINE2
# 0            32
# 1            60
# ...

# %%
for i in a:
    test[i]=le.fit_transform(test[i].astype(str))
test
# Out:
#       RESTAURANT_ID  CITY  LOCALITY  RATING  VOTES  TITLE1  CUISINE1  CUISINE2
# 0              4085     7       656     4.3    564       5        59        19
# 1             12680     6       216     4.2     61      22        72        24
# 2              1411     6       404     3.8    350       5        59        70
# 3               204     2       520     3.8   1445      19        11        59
# 4             13453     5       294     3.6     23      22        72        42
# ...             ...   ...       ...     ...    ...     ...       ...       ...
# 4226           9057     2       591     3.9    287       5        59        57
# 4227           1247     0       246     4.3    469      19        11        60
# 4228           8617     2       690     3.7     53      22        21        60
# 4229           6485     5       326     0.0      0      22        66        10
# 4230           2421     6       572     3.7     63      22        56        59
#
# [4194 rows x 8 columns]

# %%
#ID is not important for modelling and is thus dropped
train.drop(['RESTAURANT_ID'],axis=1,inplace=True)
test.drop(['RESTAURANT_ID'],axis=1,inplace=True)

# %%
#Outliers check and treatment 
from scipy.stats import zscore 
threhold=3 
z=np.abs(zscore(train)) 
print(np.where(z>3))
# Out:
# (array([   84,   185,   195,   206,   290,   300,   301,   305,   334,
#          341,   351,   376,   417,   426,   463,   495,   503,   555,
#          722,   766,   786,   826,   839,   842,   859,   900,   953,
#          954,   960,  1019,  1023,  1117,  1118,  1131,  1135,  1177,
#         1227,  1271,  1327,  1328,  1376,  1448,  1451,  1456,  1457,
#         1503,  1521,  1575,  1596,  1611,  1636,  1660,  1664,  1755,
#         1803,  1825,  1853,  1859,  1891,  1905,  1906,  2063,  2073,
#         2084,  2177,  2178,  2180,  2241,  2275,  2278,  2305,  2311,
#         2321,  2341,  2431,  2460,  2502,  2573,  2579,  2591,  2652,
#         2655,  2658,  2664,  2709,  2854,  2873,  2907,  2940,  2944,
#         2968,  2994,  2999,  3002,  3015,  3161,  3175,  3253,  3273,
#         3297,  3302,  3360,  3362,  3372,  3455,  3470,  3489,  3495,
#         3517,  3541,  3550,  3566,  3650,  3654,  3666,  3668,  3677,
# ...

# %%
train=train[(z<3).all(axis=1)] 
train
# Out:
#        CITY  LOCALITY  RATING  VOTES  COST  TITLE1  CUISINE1  CUISINE2
# 0         6       279     3.6     49  1200       4        59        32
# 1         1      1035     4.2     30  1500       4         6        60
# 2         1      1090     3.8    221   800       4        72        23
# 3         6       127     4.1     24   800      21       100        23
# 4         6       613     3.8    165   300       8        28        65
# ...     ...       ...     ...    ...   ...     ...       ...       ...
# 12685     4       333     3.8    546   500      21        72        17
# 12686     6       124     4.3   1214  1800       4        37        25
# 12687     6      1335     4.0    608  1300      14        34        25
# 12688     1       619     3.5     32   400       4        72        85
# 12689     4      1326     3.4    677   600       4        72        23
#
# [12155 rows x 8 columns]

# %%
train.describe()
# Out:
#                CITY      LOCALITY        RATING         VOTES          COST  \
# count  12155.000000  12155.000000  12155.000000  12155.000000  12155.000000
# mean       3.082106    648.757384      3.401818    304.473632    591.879967
# std        2.358869    398.265523      1.183756    447.691136    445.795769
# min        0.000000      0.000000      0.000000      0.000000     20.000000
# 25%        1.000000    330.000000      3.400000     38.000000    300.000000
# 50%        3.000000    581.000000      3.800000    124.000000    450.000000
# 75%        5.000000   1000.000000      4.000000    374.000000    700.000000
# max        8.000000   1394.000000      4.900000   2811.000000   2500.000000
#
#              TITLE1      CUISINE1      CUISINE2
# count  12155.000000  12155.000000  12155.000000
# mean      11.619663     49.318717     48.066063
# std        8.305835     28.630394     24.391920
# min        0.000000      0.000000      0.000000
# ...

# %% [markdown]
# EDA

# %%
train.corr()
# Out:
#               CITY  LOCALITY    RATING     VOTES      COST    TITLE1  \
# CITY      1.000000 -0.015655 -0.113260  0.040206  0.018512 -0.075550
# LOCALITY -0.015655  1.000000 -0.019001 -0.045064 -0.017557  0.033498
# RATING   -0.113260 -0.019001  1.000000  0.351040  0.243811 -0.114122
# VOTES     0.040206 -0.045064  0.351040  1.000000  0.399240 -0.202767
# COST      0.018512 -0.017557  0.243811  0.399240  1.000000 -0.393919
# TITLE1   -0.075550  0.033498 -0.114122 -0.202767 -0.393919  1.000000
# CUISINE1 -0.006357  0.018584 -0.022926 -0.030686 -0.051684  0.214194
# CUISINE2  0.010277  0.018489 -0.058063 -0.061745 -0.063930  0.108146
#
#           CUISINE1  CUISINE2
# CITY     -0.006357  0.010277
# LOCALITY  0.018584  0.018489
# RATING   -0.022926 -0.058063
# VOTES    -0.030686 -0.061745
# COST     -0.051684 -0.063930
# TITLE1    0.214194  0.108146
# CUISINE1  1.000000  0.021694
# CUISINE2  0.021694  1.000000

# %%
#Correlation 
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
sns.heatmap(train.corr(),annot=True)

# %% [markdown]
# no significant correlation found

# %%
plt.figure()
train['CITY'].plot(kind='hist',bins=20)

# %% [markdown]
# City 1 has the highest frequency

# %%
plt.figure()
train['LOCALITY'].plot(kind='hist',bins=20)

# %% [markdown]
# Locality 450 has the highest frequency

# %%
plt.figure()
train['RATING'].plot(kind='hist',bins=20)

# %% [markdown]
# Rating =3.8 has the highest frequency

# %%
plt.figure()
train['VOTES'].plot(kind='hist',bins=20)

# %% [markdown]
# 0-100 votes has the highest frequency

# %%
plt.figure()
train['TITLE1'].plot(kind='hist',bins=20)

# %% [markdown]
# Title 21 has the highest frequency

# %%
plt.figure()
train['CUISINE1'].plot(kind='hist',bins=20)

# %% [markdown]
# CUISINE1=72 has the highest frequency

# %%
plt.figure()
train['CUISINE2'].plot(kind='hist',bins=20)

# %% [markdown]
# CUISINE2=72 has the highest frequency

# %%
plt.figure()
train['COST'].plot(kind='hist',bins=20)

# %% [markdown]
# Cost =480(approx) has the highest frequency

# %%
plt.figure()
sns.pairplot(train)

# %%
for i in train.columns:
    plt.figure()
    sns.lineplot(i,'COST',data=train)

# %%
for i in train.columns:
    plt.figure()
    sns.barplot(i,'COST',data=train)

# %%
for i in train.columns:
    plt.figure()
    sns.regplot(i,'COST',data=train)

# %% [markdown]
# City 3 has the highest cost and 5 has the lowest.Title 6 has the highest cost and 19 has the lowest. Cost increases with increase in ratings and votes.cost drops with increase in Cuisine 1 an 2 categories.

# %%
train.drop(['LOCALITY'],axis=1,inplace=True)
test.drop(['LOCALITY'],axis=1,inplace=True)

# %%
#X y division of data
x=train.drop(['COST'],axis=1)
y=train['COST']
y=y.values.reshape(-1,1)
y.shape
# Out:
# (12155, 1)

# %%
#Scaling data
import sklearn
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
dx=scale.fit_transform(x)
x=pd.DataFrame(dx,columns=x.columns)
x
# Out:
#            CITY    RATING     VOTES    TITLE1  CUISINE1  CUISINE2
# 0      1.237039  0.167425 -0.570671 -0.917424  0.338161 -0.658690
# 1     -0.882708  0.674306 -0.613112 -0.917424 -1.513095  0.489278
# 2     -0.882708  0.336385 -0.186461 -0.917424  0.792243 -1.027680
# 3      1.237039  0.589826 -0.626515  1.129414  1.770264 -1.027680
# 4      1.237039  0.336385 -0.311553 -0.435816 -0.744649  0.694272
# ...         ...       ...       ...       ...       ...       ...
# 12150  0.389141  0.336385  0.539515  1.129414  0.792243 -1.273673
# 12151  1.237039  0.758787  2.031677 -0.917424 -0.430285 -0.945683
# 12152  1.237039  0.505346  0.678010  0.286598 -0.535073 -0.945683
# 12153 -0.882708  0.082944 -0.608645 -0.917424  0.792243  1.514250
# 12154  0.389141 -0.001536  0.832140 -0.917424  0.792243 -1.027680
#
# [12155 rows x 6 columns]

# %%
dt=scale.fit_transform(test)
test=pd.DataFrame(dt,columns=test.columns)
test
# Out:
#           CITY    RATING     VOTES    TITLE1  CUISINE1  CUISINE2
# 0     1.665575  0.742821  0.215847 -0.886079  0.834726 -1.033117
# 1     1.235703  0.658141 -0.409980  1.146274  1.394687 -0.803435
# 2     1.235703  0.319419 -0.050409 -0.886079  0.834726  1.309632
# 3    -0.483785  0.319419  1.311978  0.787623 -1.232826  0.804334
# 4     0.805831  0.150058 -0.457259  1.146274  1.394687  0.023417
# ...        ...       ...       ...       ...       ...       ...
# 4189 -0.483785  0.404100 -0.128793 -0.886079  0.834726  0.712461
# 4190 -1.343530  0.742821  0.097650  0.787623 -1.232826  0.850270
# 4191 -0.483785  0.234739 -0.419933  1.146274 -0.802086  0.850270
# 4192  0.805831 -2.898437 -0.485875  1.146274  1.136243 -1.446543
# 4193  1.235703  0.234739 -0.407491  1.146274  0.705504  0.804334
#
# [4194 rows x 6 columns]

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.externals import joblib

# %%
#Calculating best r score
def max_score(model):
    max_score=0
    for r_state in range(42,100):
        xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=r_state,test_size=0.20)
        model.fit(xtrain,ytrain)
        ypred=model.predict(xtest)
        r2=r2_score(ytest,ypred)
        if r2>max_score:
            max_score=r2
            final_r_state=r_state
    print(max_score,'is max accuracy against r_state',final_r_state)

# %%
lr=LinearRegression()
max_score(lr)
# Out:
# 0.31119328062122775 is max accuracy against r_state 99

# %%
alpha={'alpha':[.0001,.001,.01,.1,1,10]}
grid=GridSearchCV(estimator=Ridge(),param_grid=alpha)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'alpha': 10}

# %%
rd=Ridge(alpha=10)
max_score(rd)
# Out:
# 0.3111520864870324 is max accuracy against r_state 99

# %%
alpha={'alpha':[.0001,.001,.01,.1,1,10]}
grid1=GridSearchCV(estimator=Lasso(),param_grid=alpha)
grid1.fit(x,y)
print(grid1.best_params_)
# Out:
# {'alpha': 1}

# %%
ls=Lasso(alpha=1)
max_score(ls)
# Out:
# 0.31117373783455304 is max accuracy against r_state 99

# %%
alpha={'alpha':[.0001,.001,.01,.1,1,10]}
grid=GridSearchCV(estimator=ElasticNet(),param_grid=alpha)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'alpha': 0.01}

# %%
en=ElasticNet(alpha=0.01)
max_score(en)
# Out:
# 0.3109903805261447 is max accuracy against r_state 99

# %%
from sklearn.svm import SVR
para={'kernel':['rbf','linear','poly']}
grid=GridSearchCV(estimator=SVR(),param_grid=para)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'kernel': 'linear'}

# %%
svr=SVR(kernel='linear')
max_score(svr)
# Out:
# 0.27177581142541785 is max accuracy against r_state 99

# %%
from sklearn.neighbors import KNeighborsRegressor
#Knr
n_neighbors={'n_neighbors':[2,3,4,5,6,7,8,9]}
grid=GridSearchCV(estimator=KNeighborsRegressor(),param_grid=n_neighbors)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'n_neighbors': 7}

# %%
knr=KNeighborsRegressor(n_neighbors=7)
max_score(knr)
# Out:
# 0.4514488828303166 is max accuracy against r_state 99

# %%
from sklearn.tree import DecisionTreeRegressor
para={'criterion':['mse','mae','friedman_mse']}
grid=GridSearchCV(estimator=DecisionTreeRegressor(),param_grid=para)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'criterion': 'friedman_mse'}

# %%
dtr=DecisionTreeRegressor(criterion='mse')
max_score(dtr)
# Out:
# 0.4561769961459359 is max accuracy against r_state 72

# %%
import xgboost
from xgboost import XGBRegressor

# %%
xgbr=XGBRegressor()
max_score(xgbr)
# Out:
# 0.716140820416154 is max accuracy against r_state 52

# %%
from sklearn.ensemble import GradientBoostingRegressor
para={'n_estimators':[100,200,300,500],'learning_rate':[1,0.1,0.01,0.001]}
grid=GridSearchCV(estimator=GradientBoostingRegressor(),param_grid=para)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'learning_rate': 0.1, 'n_estimators': 500}

# %%
gdr=GradientBoostingRegressor(learning_rate=0.1,n_estimators=500)
max_score(gdr)
# Out:
# 0.7226814318369935 is max accuracy against r_state 52

# %%
from sklearn.ensemble import RandomForestRegressor
para={'n_estimators':[100,200,300,500]}
grid=GridSearchCV(estimator=RandomForestRegressor(),param_grid=para)
grid.fit(x,y)
print(grid.best_params_)
# Out:
# {'n_estimators': 500}

# %%
rfr=RandomForestRegressor(n_estimators=500)
max_score(rfr)
# Out:
# 0.7093686620462776 is max accuracy against r_state 48

# %%
models=[]
models.append(('Linear Regression',lr,99))
models.append(('Lasso Regression',ls,99))
models.append(('Ridge regression',rd,99))
models.append(('Elastic Net',en,99))
models.append(('Support Vector Regressor',svr,99))
models.append(('KNeighborsRegressor',knr,99))
models.append(('DecisionTreeRegressor',dtr,72))
models.append(('XGBoostRegressor',xgbr,52))
models.append(('GradientBoostingRegressor',gdr,52))
models.append(('RandomForestRegressor',rfr,48))

Model=[]
R2Score=[]
Cvs=[]
MAE=[]
MSE=[]
RMSE=[]

# %%
for name,model,randomstate in models:
    print('***********',name,'************')
    print('\n')
    Model.append(name)
    xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=randomstate,test_size=0.20)
    model.fit(xtrain,ytrain)
    print(model)
    pred=model.predict(xtest)
    print('\n')
    R2=r2_score(ytest,pred)
    print('R2 score=',R2)
    R2Score.append(R2*100)
    print('\n')
    cvs=cross_val_score(model,x,y,cv=5,scoring='r2').mean()
    print('Cross Validation Score=',cvs)
    Cvs.append(cvs)
    print('\n')
    mae=mean_absolute_error(ytest,pred)
    print('Mean Absolute Error=',mae)
    MAE.append(mae)
    print('\n')
    mse=mean_squared_error(ytest,pred)
    print("Mean Squared Error=",mse)
    MSE.append(mse)
    print('\n')
    rmse=np.sqrt(mean_squared_error(ytest,pred))
    print('Root Mean Squared Error=',rmse)
    RMSE.append(rmse)
# Out:
# *********** Linear Regression ************
#
#
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
#
#
# R2 score= 0.31119328062122775
#
#
# Cross Validation Score= 0.26996729402683595
#
#
# Mean Absolute Error= 256.1448517726011
#
#
# Mean Squared Error= 137595.59875311513
#
#
# Root Mean Squared Error= 370.93880728917424
# *********** Lasso Regression ************
#
#
# Lasso(alpha=1, copy_X=True, fit_intercept=True, max_iter=1000, normalize=False,
#       positive=False, precompute=False, random_state=None, selection='cyclic',
#       tol=0.0001, warm_start=False)
#
#
# R2 score= 0.31117373783455304
#
#
# Cross Validation Score= 0.2700257525610152
#
#
# Mean Absolute Error= 256.01995163485736
#
#
# Mean Squared Error= 137599.50260793848
#
#
# Root Mean Squared Error= 370.9440693796552
# *********** Ridge regression ************
#
#
# Ridge(alpha=10, copy_X=True, fit_intercept=True, max_iter=None, normalize=False,
# ...

# %%
Result=pd.DataFrame({'Model':Model,'R2_Score':R2Score,'Cross Validation Score':Cvs,'Mean Absolute Error':MAE,'Mean Squared Error':MSE,'Root Mean Squared Error':RMSE})
Result
# Out:
#                        Model   R2_Score  Cross Validation Score  \
# 0          Linear Regression  31.119328                0.269967
# 1           Lasso Regression  31.117374                0.270026
# 2           Ridge regression  31.115209                0.269969
# 3                Elastic Net  31.099038                0.269972
# 4   Support Vector Regressor  27.177581                0.224558
# 5        KNeighborsRegressor  45.144888                0.394408
# 6      DecisionTreeRegressor  45.414514                0.372626
# 7           XGBoostRegressor  71.614082                0.686243
# 8  GradientBoostingRegressor  72.279818                0.697820
# 9      RandomForestRegressor  70.800342                0.661393
#
#    Mean Absolute Error  Mean Squared Error  Root Mean Squared Error
# 0           256.144852       137595.598753               370.938807
# 1           256.019952       137599.502608               370.944069
# ...

# %%
#saving the model
joblib.dump(gdr,'gdr.restaurant.obj')
# Out:
# ['gdr.restaurant.obj']

# %%
#Loading the data
GDR=joblib.load('gdr.restaurant.obj')

# %%
#prediction
GDR.fit(x,y)
prediction=GDR.predict(test)
print(prediction)
# Out:
# [950.13024557 927.23990891 621.05889885 ... 408.65551709 331.72553246
#  424.35751058]

# %%
test['Pred']=prediction
test
# Out:
#           CITY    RATING     VOTES    TITLE1  CUISINE1  CUISINE2        Pred
# 0     1.665575  0.742821  0.215847 -0.886079  0.834726 -1.033117  950.130246
# 1     1.235703  0.658141 -0.409980  1.146274  1.394687 -0.803435  927.239909
# 2     1.235703  0.319419 -0.050409 -0.886079  0.834726  1.309632  621.058899
# 3    -0.483785  0.319419  1.311978  0.787623 -1.232826  0.804334  605.292261
# 4     0.805831  0.150058 -0.457259  1.146274  1.394687  0.023417  781.825601
# ...        ...       ...       ...       ...       ...       ...         ...
# 4189 -0.483785  0.404100 -0.128793 -0.886079  0.834726  0.712461  800.991929
# 4190 -1.343530  0.742821  0.097650  0.787623 -1.232826  0.850270  529.352489
# 4191 -0.483785  0.234739 -0.419933  1.146274 -0.802086  0.850270  408.655517
# 4192  0.805831 -2.898437 -0.485875  1.146274  1.136243 -1.446543  331.725532
# 4193  1.235703  0.234739 -0.407491  1.146274  0.705504  0.804334  424.357511
#
# [4194 rows x 7 columns]
